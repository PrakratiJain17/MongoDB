# %%
#Write a Python script to load the Superstore dataset from a CSV file into MongoDB
import pandas as pd
from pymongo import MongoClient

# MongoDB connection (Update if using a remote server)
client = MongoClient("mongodb://localhost:27017/")  

# Connect to the 'mongo' database and 'superstore_data' collection
db = client["Mongo"]
collection = db["Superstore_Data"]

# Load CSV into Pandas DataFrame
csv_file = "superstore.csv"  # Update with the correct path
df = pd.read_csv(csv_file)

# Convert DataFrame to a list of dictionaries
data = df.to_dict(orient="records")

# Insert data into MongoDB
if data:
    collection.insert_many(data)
    print(f" Successfully inserted {len(data)} records into MongoDB!")
else:
    print("No data found in CSV.")

# Verify insertion
print("Sample Record from MongoDB:")
print(collection.find_one())
# Out:
#  Successfully inserted 9994 records into MongoDB!
# Sample Record from MongoDB:
# {'_id': ObjectId('67adea81fe577b36e5568459'), 'Row ID': 1, 'Order ID': 'CA-2016-152156', 'Order Date': '11-08-2016', 'Ship Date': '11-11-2016', 'Ship Mode': 'Second Class', 'Customer ID': 'CG-12520', 'Customer Name': 'Claire Gute', 'Segment': 'Consumer', 'Country': 'United States', 'City': 'Henderson', 'State': 'Kentucky', 'Postal Code': 42420, 'Region': 'South', 'Product ID': 'FUR-BO-10001798', 'Category': 'Furniture', 'Sub-Category': 'Bookcases', 'Product Name': 'Bush Somerset Collection Bookcase', 'Sales': 261.96, 'Quantity': 2, 'Discount': 0.0, 'Profit': 41.9136}

# %%
#2.Retrieve and print all documents from the Orders collection
from pymongo import MongoClient
import pprint  # For better formatting

# Connect to MongoDB
client = MongoClient("mongodb://localhost:27017/")  

# Select the database and collection
db = client["Mongo"]  # Use your database name
collection = db["Superstore_Data"]  # Use your collection name

# Retrieve and print all documents
for document in collection.find().limit(1):
    pprint.pprint(document)  # Pretty print each document
# Out:
# {'Category': 'Furniture',
#  'City': 'Henderson',
#  'Country': 'United States',
#  'Customer ID': 'CG-12520',
#  'Customer Name': 'Claire Gute',
#  'Discount': 0.0,
#  'Order Date': '11-08-2016',
#  'Order ID': 'CA-2016-152156',
#  'Postal Code': 42420,
#  'Product ID': 'FUR-BO-10001798',
#  'Product Name': 'Bush Somerset Collection Bookcase',
#  'Profit': 41.9136,
#  'Quantity': 2,
#  'Region': 'South',
#  'Row ID': 1,
#  'Sales': 261.96,
#  'Segment': 'Consumer',
#  'Ship Date': '11-11-2016',
#  'Ship Mode': 'Second Class',
#  'State': 'Kentucky',
#  'Sub-Category': 'Bookcases',
#  '_id': ObjectId('67adea81fe577b36e5568459')}

# %%
#3.Count and display the total number of documents in the Orders collection
total_documents = collection.count_documents({})
print("Total number of documents:", total_documents)
# Out:
# Total number of documents: 9994

# %%
#4.Write a query to fetch all orders from the "West" region
west_orders = collection.find({"Region": "West"})

# Print the orders
for order in west_orders:
    pprint.pprint(order)
# Out:
# {'Category': 'Technology',
#  'City': 'Los Angeles',
#  'Country': 'United States',
#  'Customer ID': 'BH-11710',
#  'Customer Name': 'Brosina Hoffman',
#  'Discount': 0.2,
#  'Order Date': '06-09-2014',
#  'Order ID': 'CA-2014-115812',
#  'Postal Code': 90032,
#  'Product ID': 'TEC-PH-10002275',
#  'Product Name': 'Mitel 5320 IP Phone VoIP phone',
#  'Profit': 90.7152,
#  'Quantity': 6,
#  'Region': 'West',
#  'Row ID': 8,
#  'Sales': 907.152,
#  'Segment': 'Consumer',
#  'Ship Date': '6/14/2014',
#  'Ship Mode': 'Standard Class',
#  'State': 'California',
#  'Sub-Category': 'Phones',
#  '_id': ObjectId('67adea81fe577b36e5568460')}
# {'Category': 'Office Supplies',
#  'City': 'Los Angeles',
#  'Country': 'United States',
#  'Customer ID': 'BH-11710',
#  'Customer Name': 'Brosina Hoffman',
#  'Discount': 0.0,
#  'Order Date': '06-09-2014',
#  'Order ID': 'CA-2014-115812',
#  'Postal Code': 90032,
#  'Product ID': 'OFF-AP-10002892',
#  'Product Name': 'Belkin F5C206VTEL 6 Outlet Surge',
#  'Profit': 34.47,
#  'Quantity': 5,
#  'Region': 'West',
#  'Row ID': 10,
#  'Sales': 114.9,
#  'Segment': 'Consumer',
#  'Ship Date': '6/14/2014',
#  'Ship Mode': 'Standard Class',
#  'State': 'California',
#  'Sub-Category': 'Appliances',
#  '_id': ObjectId('67adea81fe577b36e5568462')}
# {'Category': 'Furniture',
#  'City': 'Los Angeles',
#  'Country': 'United States',
#  'Customer ID': 'BH-11710',
#  'Customer Name': 'Brosina Hoffman',
#  'Discount': 0.2,
#  'Order Date': '06-09-2014',
#  'Order ID': 'CA-2014-115812',
#  'Postal Code': 90032,
#  'Product ID': 'FUR-TA-10001539',
#  'Product Name': 'Chromcraft Rectangular Conference Tables',
#  'Profit': 85.3092,
#  'Quantity': 9,
#  'Region': 'West',
#  'Row ID': 11,
#  'Sales': 1706.184,
#  'Segment': 'Consumer',
#  'Ship Date': '6/14/2014',
#  'Ship Mode': 'Standard Class',
#  'State': 'California',
#  'Sub-Category': 'Tables',
#  '_id': ObjectId('67adea81fe577b36e5568463')}
# {'Category': 'Technology',
#  'City': 'Los Angeles',
#  'Country': 'United States',
#  'Customer ID': 'BH-11710',
#  'Customer Name': 'Brosina Hoffman',
#  'Discount': 0.2,
#  'Order Date': '06-09-2014',
#  'Order ID': 'CA-2014-115812',
#  'Postal Code': 90032,
#  'Product ID': 'TEC-PH-10002033',
#  'Product Name': 'Konftel 250 Conference\xa0phone\xa0- Charcoal black',
#  'Profit': 68.3568,
#  'Quantity': 4,
#  'Region': 'West',
#  'Row ID': 12,
#  'Sales': 911.424,
#  'Segment': 'Consumer',
#  'Ship Date': '6/14/2014',
#  'Ship Mode': 'Standard Class',
#  'State': 'California',
#  'Sub-Category': 'Phones',
#  '_id': ObjectId('67adea81fe577b36e5568464')}
# {'Category': 'Office Supplies',
#  'City': 'Seattle',
#  'Country': 'United States',
#  'Customer ID': 'IM-15070',
#  'Customer Name': 'Irene Maddox',
#  'Discount': 0.2,
#  'Order Date': '12-05-2016',
#  'Order ID': 'CA-2016-161389',
#  'Postal Code': 98103,
#  'Product ID': 'OFF-BI-10003656',
#  'Product Name': 'Fellowes PB200 Plastic Comb Binding Machine',
#  'Profit': 132.5922,
#  'Quantity': 3,
#  'Region': 'West',
#  'Row ID': 14,
#  'Sales': 407.976,
#  'Segment': 'Consumer',
#  'Ship Date': '12-10-2016',
#  'Ship Mode': 'Standard Class',
#  'State': 'Washington',
#  'Sub-Category': 'Binders',
#  '_id': ObjectId('67adea81fe577b36e5568466')}
# {'Category': 'Office Supplies',
#  'City': 'West Jordan',
#  'Country': 'United States',
#  'Customer ID': 'AG-10270',
#  'Customer Name': 'Alejandro Grove',
#  'Discount': 0.0,
#  'Order Date': '5/13/2014',
#  'Order ID': 'CA-2014-167164',
#  'Postal Code': 84084,
#  'Product ID': 'OFF-ST-10000107',
#  'Product Name': 'Fellowes Super Stor/Drawer',
#  'Profit': 9.99,
#  'Quantity': 2,
#  'Region': 'West',
#  'Row ID': 18,
#  'Sales': 55.5,
#  'Segment': 'Consumer',
#  'Ship Date': '5/15/2014',
#  'Ship Mode': 'Second Class',
#  'State': 'Utah',
#  'Sub-Category': 'Storage',
#  '_id': ObjectId('67adea81fe577b36e556846a')}
# {'Category': 'Technology',
#  'City': 'San Francisco',
#  'Country': 'United States',
#  'Customer ID': 'ZD-21925',
#  'Customer Name': 'Zuschuss Donatelli',
#  'Discount': 0.2,
#  'Order Date': '8/27/2014',
#  'Order ID': 'CA-2014-143336',
#  'Postal Code': 94109,
#  'Product ID': 'TEC-PH-10001949',
#  'Product Name': 'Cisco SPA 501G IP Phone',
#  'Profit': 16.011,
#  'Quantity': 3,
#  'Region': 'West',
#  'Row ID': 20,
#  'Sales': 213.48,
#  'Segment': 'Consumer',
#  'Ship Date': '09-01-2014',
#  'Ship Mode': 'Second Class',
#  'State': 'California',
#  'Sub-Category': 'Phones',
#  '_id': ObjectId('67adea81fe577b36e556846c')}
# {'Category': 'Furniture',
#  'City': 'Orem',
#  'Country': 'United States',
#  'Customer ID': 'EB-13870',
#  'Customer Name': 'Emily Burns',
#  'Discount': 0.0,
#  'Order Date': '9/25/2015',
#  'Order ID': 'CA-2015-106320',
#  'Postal Code': 84057,
#  'Product ID': 'FUR-TA-10000577',
#  'Product Name': 'Bretford CR4500 Series Slim Rectangular Table',
#  'Profit': 240.2649,
#  'Quantity': 3,
#  'Region': 'West',
#  'Row ID': 25,
#  'Sales': 1044.63,
#  'Segment': 'Consumer',
#  'Ship Date': '9/30/2015',
#  'Ship Mode': 'Standard Class',
#  'State': 'Utah',
#  'Sub-Category': 'Tables',
#  '_id': ObjectId('67adea81fe577b36e5568471')}
# {'Category': 'Technology',
#  'City': 'Los Angeles',
#  'Country': 'United States',
#  'Customer ID': 'EH-13945',
#  'Customer Name': 'Eric Hoffmann',
#  'Discount': 0.0,
#  'Order Date': '1/16/2016',
#  'Order ID': 'CA-2016-121755',
#  'Postal Code': 90049,
#  'Product ID': 'TEC-AC-10003027',
#  'Product Name': 'Imation\xa08GB Mini TravelDrive USB 2.0\xa0Flash Drive',
#  'Profit': 11.7741,
#  'Quantity': 3,
#  'Region': 'West',
#  'Row ID': 27,
#  'Sales': 90.57,
#  'Segment': 'Consumer',
#  'Ship Date': '1/20/2016',
#  'Ship Mode': 'Second Class',
#  'State': 'California',
#  'Sub-Category': 'Accessories',
#  '_id': ObjectId('67adea81fe577b36e5568473')}
# {'Category': 'Office Supplies',
#  'City': 'Los Angeles',
#  'Country': 'United States',
#  'Customer ID': 'RA-19885',
#  'Customer Name': 'Ruben Ausman',
#  'Discount': 0.0,
#  'Order Date': '7/17/2016',
#  'Order ID': 'CA-2016-101343',
#  'Postal Code': 90049,
#  'Product ID': 'OFF-ST-10003479',
#  'Product Name': 'Eldon Base for stackable storage shelf, platinum',
#  'Profit': 3.894,
#  'Quantity': 2,
#  'Region': 'West',
#  'Row ID': 43,
#  'Sales': 77.88,
#  'Segment': 'Corporate',
#  'Ship Date': '7/22/2016',
#  'Ship Mode': 'Standard Class',
#  'State': 'California',
#  'Sub-Category': 'Storage',
#  '_id': ObjectId('67adea81fe577b36e5568483')}
# {'Category': 'Office Supplies',
#  'City': 'Los Angeles',
#  'Country': 'United States',
#  'Customer ID': 'KM-16720',
#  'Customer Name': 'Kunst Miller',
#  'Discount': 0.0,
#  'Order Date': '11/24/2015',
#  'Order ID': 'CA-2015-135545',
#  'Postal Code': 90004,
#  'Product ID': 'OFF-PA-10003892',
#  'Product Name': 'Xerox 1943',
#  'Profit': 68.9631,
#  'Quantity': 3,
#  'Region': 'West',
#  'Row ID': 65,
#  'Sales': 146.73,
#  'Segment': 'Consumer',
#  'Ship Date': '11/30/2015',
#  'Ship Mode': 'Standard Class',
#  'State': 'California',
#  'Sub-Category': 'Paper',
#  '_id': ObjectId('67adea81fe577b36e5568499')}
# {'Category': 'Furniture',
#  'City': 'Los Angeles',
#  'Country': 'United States',
#  'Customer ID': 'KM-16720',
#  'Customer Name': 'Kunst Miller',
#  'Discount': 0.0,
#  'Order Date': '11/24/2015',
#  'Order ID': 'CA-2015-135545',
#  'Postal Code': 90004,
#  'Product ID': 'FUR-FU-10000397',
#  'Product Name': 'Luxo Economy Swing Arm Lamp',
#  'Profit': 22.3328,
#  'Quantity': 4,
#  'Region': 'West',
#  'Row ID': 66,
#  'Sales': 79.76,
#  'Segment': 'Consumer',
#  'Ship Date': '11/30/2015',
#  'Ship Mode': 'Standard Class',
#  'State': 'California',
#  'Sub-Category': 'Furnishings',
#  '_id': ObjectId('67adea81fe577b36e556849a')}
# {'Category': 'Office Supplies',
#  'City': 'Gilbert',
#  'Country': 'United States',
#  'Customer ID': 'BS-11590',
#  'Customer Name': 'Brendan Sweed',
#  'Discount': 0.2,
#  'Order Date': '12-05-2014',
#  'Order ID': 'CA-2014-106376',
#  'Postal Code': 85234,
#  'Product ID': 'OFF-AR-10002671',
#  'Product Name': 'Hunt BOSTON Model 1606 High-Volume Electric Pencil '
#                  'Sharpener, Beige',
#  'Profit': 111.3024,
#  'Quantity': 8,
#  'Region': 'West',
#  'Row ID': 68,
#  'Sales': 1113.024,
#  'Segment': 'Corporate',
#  'Ship Date': '12-10-2014',
#  'Ship Mode': 'Standard Class',
#  'State': 'Arizona',
#  'Sub-Category': 'Art',
#  '_id': ObjectId('67adea81fe577b36e556849c')}
# {'Category': 'Technology',
#  'City': 'Gilbert',
#  'Country': 'United States',
#  'Customer ID': 'BS-11590',
#  'Customer Name': 'Brendan Sweed',
#  'Discount': 0.2,
#  'Order Date': '12-05-2014',
#  'Order ID': 'CA-2014-106376',
#  'Postal Code': 85234,
#  'Product ID': 'TEC-PH-10002726',
#  'Product Name': 'netTALK DUO VoIP Telephone Service',
#  'Profit': 62.988,
#  'Quantity': 4,
#  'Region': 'West',
#  'Row ID': 69,
#  'Sales': 167.968,
#  'Segment': 'Corporate',
#  'Ship Date': '12-10-2014',
#  'Ship Mode': 'Standard Class',
#  'State': 'Arizona',
#  'Sub-Category': 'Phones',
#  '_id': ObjectId('67adea81fe577b36e556849d')}
# {'Category': 'Technology',
#  'City': 'Los Angeles',
#  'Country': 'United States',
#  'Customer ID': 'JS-15685',
#  'Customer Name': 'Jim Sink',
#  'Discount': 0.2,
#  'Order Date': '9/17/2016',
#  'Order ID': 'CA-2016-109806',
#  'Postal Code': 90036,
#  'Product ID': 'TEC-PH-10004093',
#  'Product Name': 'Panasonic Kx-TS550',
#  'Profit': 8.2782,
#  'Quantity': 2,
#  'Region': 'West',
#  'Row ID': 91,
#  'Sales': 73.584,
#  'Segment': 'Corporate',
#  'Ship Date': '9/22/2016',
#  'Ship Mode': 'Standard Class',
#  'State': 'California',
#  'Sub-Category': 'Phones',
#  '_id': ObjectId('67adea81fe577b36e55684b3')}
# {'Category': 'Office Supplies',
#  'City': 'San Francisco',
#  'Country': 'United States',
#  'Customer ID': 'KD-16345',
#  'Customer Name': 'Katherine Ducich',
#  'Discount': 0.2,
#  'Order Date': '6/17/2017',
#  'Order ID': 'CA-2017-157833',
#  'Postal Code': 94122,
#  'Product ID': 'OFF-BI-10001721',
#  'Product Name': 'Trimflex Flexible Post Binders',
#  'Profit': 17.9592,
#  'Quantity': 3,
#  'Region': 'West',
#  'Row ID': 98,
#  'Sales': 51.312,
#  'Segment': 'Consumer',
#  'Ship Date': '6/20/2017',
#  'Ship Mode': 'Premium Class',
#  'State': 'California',
#  'Sub-Category': 'Binders',
#  '_id': ObjectId('67adea81fe577b36e55684ba')}
# {'Category': 'Technology',
#  'City': 'Aurora',
#  'Country': 'United States',
#  'Customer ID': 'LC-16870',
#  'Customer Name': 'Lena Cacioppo',
#  'Discount': 0.2,
#  'Order Date': '11/13/2015',
#  'Order ID': 'US-2015-156867',
#  'Postal Code': 80013,
#  'Product ID': 'TEC-AC-10001552',
#  'Product Name': 'Logitech K350 2.4Ghz Wireless Keyboard',
#  'Profit': -26.8758,
#  'Quantity': 6,
#  'Region': 'West',
#  'Row ID': 104,
#  'Sales': 238.896,
#  'Segment': 'Consumer',
#  'Ship Date': '11/17/2015',
#  'Ship Mode': 'Standard Class',
#  'State': 'Colorado',
#  'Sub-Category': 'Accessories',
#  '_id': ObjectId('67adea81fe577b36e55684c0')}
# {'Category': 'Furniture',
#  'City': 'Aurora',
#  'Country': 'United States',
#  'Customer ID': 'LC-16870',
#  'Customer Name': 'Lena Cacioppo',
#  'Discount': 0.2,
#  'Order Date': '11/13/2015',
#  'Order ID': 'US-2015-156867',
#  'Postal Code': 80013,
#  'Product ID': 'FUR-FU-10004006',
#  'Product Name': 'Deflect-o DuraMat Lighweight, Studded, Beveled Mat for Low '
#                  'Pile Carpeting',
#  'Profit': -3.8385,
#  'Quantity': 3,
#  'Region': 'West',
#  'Row ID': 105,
#  'Sales': 102.36,
#  'Segment': 'Consumer',
#  'Ship Date': '11/17/2015',
#  'Ship Mode': 'Standard Class',
#  'State': 'Colorado',
#  'Sub-Category': 'Furnishings',
#  '_id': ObjectId('67adea81fe577b36e55684c1')}
# {'Category': 'Furniture',
#  'City': 'Seattle',
#  'Country': 'United States',
#  'Customer ID': 'DK-13090',
#  'Customer Name': 'Dave Kipp',
#  'Discount': 0.0,
#  'Order Date': '03-02-2015',
#  'Order ID': 'CA-2015-110457',
#  'Postal Code': 98103,
#  'Product ID': 'FUR-TA-10001768',
#  'Product Name': 'Hon Racetrack Conference Tables',
#  'Profit': 165.3813,
#  'Quantity': 3,
#  'Region': 'West',
#  'Row ID': 118,
#  'Sales': 787.53,
#  'Segment': 'Consumer',
#  'Ship Date': '03-06-2015',
#  'Ship Mode': 'Standard Class',
#  'State': 'Washington',
#  'Sub-Category': 'Tables',
#  '_id': ObjectId('67adea81fe577b36e55684ce')}
# {'Category': 'Office Supplies',
#  'City': 'Phoenix',
#  'Country': 'United States',
#  'Customer ID': 'TS-21610',
#  'Customer Name': 'Troy Staebel',
#  'Discount': 0.2,
#  'Order Date': '11-05-2017',
#  'Order ID': 'US-2017-107272',
#  'Postal Code': 85023,
#  'Product ID': 'OFF-ST-10002974',
#  'Product Name': 'Trav-L-File Heavy-Duty Shuttle II, Black',
#  'Profit': 30.499,
#  'Quantity': 7,
#  'Region': 'West',
#  'Row ID': 128,
#  'Sales': 243.992,
#  'Segment': 'Consumer',
#  'Ship Date': '11-12-2017',
#  'Ship Mode': 'Standard Class',
#  'State': 'Arizona',
#  'Sub-Category': 'Storage',
#  '_id': ObjectId('67adea81fe577b36e55684d8')}
# {'Category': 'Furniture',
#  'City': 'Los Angeles',
#  'Country': 'United States',
#  'Customer ID': 'LS-16975',
#  'Customer Name': 'Lindsay Shagiari',
#  'Discount': 0.2,
#  'Order Date': '11-06-2016',
#  'Order ID': 'US-2016-125969',
#  'Postal Code': 90004,
#  'Product ID': 'FUR-CH-10001146',
#  'Product Name': 'Global Task Chair, Black',
#  'Profit': -9.1602,
#  'Quantity': 2,
#  'Region': 'West',
#  'Row ID': 129,
#  'Sales': 81.424,
#  'Segment': 'Home Office',
#  'Ship Date': '11-10-2016',
#  'Ship Mode': 'Second Class',
#  'State': 'California',
#  'Sub-Category': 'Chairs',
#  '_id': ObjectId('67adea81fe577b36e55684d9')}
# {'Category': 'Furniture',
#  'City': 'Los Angeles',
#  'Country': 'United States',
#  'Customer ID': 'LS-16975',
#  'Customer Name': 'Lindsay Shagiari',
#  'Discount': 0.0,
#  'Order Date': '11-06-2016',
#  'Order ID': 'US-2016-125969',
#  'Postal Code': 90004,
#  'Product ID': 'FUR-FU-10003773',
#  'Product Name': 'Eldon Cleatmat Plus Chair Mats for High Pile Carpets',
#  'Profit': 26.2416,
#  'Quantity': 3,
#  'Region': 'West',
#  'Row ID': 130,
#  'Sales': 238.56,
#  'Segment': 'Home Office',
#  'Ship Date': '11-10-2016',
#  'Ship Mode': 'Second Class',
#  'State': 'California',
#  'Sub-Category': 'Furnishings',
#  '_id': ObjectId('67adea81fe577b36e55684da')}
# {'Category': 'Office Supplies',
#  'City': 'Roseville',
#  'Country': 'United States',
#  'Customer ID': 'LC-16885',
#  'Customer Name': 'Lena Creighton',
#  'Discount': 0.2,
#  'Order Date': '10/13/2016',
#  'Order ID': 'CA-2016-145583',
#  'Postal Code': 95661,
#  'Product ID': 'OFF-BI-10004781',
#  'Product Name': 'GBC Wire Binding Strips',
#  'Profit': 26.6616,
#  'Quantity': 3,
#  'Region': 'West',
#  'Row ID': 138,
#  'Sales': 76.176,
#  'Segment': 'Consumer',
#  'Ship Date': '10/19/2016',
#  'Ship Mode': 'Standard Class',
#  'State': 'California',
#  'Sub-Category': 'Binders',
#  '_id': ObjectId('67adea81fe577b36e55684e2')}
# {'Category': 'Office Supplies',
#  'City': 'Roseville',
#  'Country': 'United States',
#  'Customer ID': 'LC-16885',
#  'Customer Name': 'Lena Creighton',
#  'Discount': 0.0,
#  'Order Date': '10/13/2016',
#  'Order ID': 'CA-2016-145583',
#  'Postal Code': 95661,
#  'Product ID': 'OFF-SU-10001218',
#  'Product Name': 'Fiskars Softgrip Scissors',
#  'Profit': 18.4464,
#  'Quantity': 6,
#  'Region': 'West',
#  'Row ID': 139,
#  'Sales': 65.88,
#  'Segment': 'Consumer',
#  'Ship Date': '10/19/2016',
#  'Ship Mode': 'Standard Class',
#  'State': 'California',
#  'Sub-Category': 'Supplies',
#  '_id': ObjectId('67adea81fe577b36e55684e3')}
# {'Category': 'Office Supplies',
#  'City': 'San Francisco',
#  'Country': 'United States',
#  'Customer ID': 'SH-19975',
#  'Customer Name': 'Sally Hughsby',
#  'Discount': 0.0,
#  'Order Date': '9/18/2017',
#  'Order ID': 'CA-2017-106180',
#  'Postal Code': 94122,
#  'Product ID': 'OFF-PA-10004327',
#  'Product Name': 'Xerox 1911',
#  'Profit': 68.976,
#  'Quantity': 3,
#  'Region': 'West',
#  'Row ID': 144,
#  'Sales': 143.7,
#  'Segment': 'Corporate',
#  'Ship Date': '9/23/2017',
#  'Ship Mode': 'Standard Class',
#  'State': 'California',
#  'Sub-Category': 'Paper',
#  '_id': ObjectId('67adea81fe577b36e55684e8')}
# {'Category': 'Office Supplies',
#  'City': 'Pasadena',
#  'Country': 'United States',
#  'Customer ID': 'HA-14920',
#  'Customer Name': 'Helen Andreada',
#  'Discount': 0.0,
#  'Order Date': '09-07-2015',
#  'Order ID': 'CA-2015-110744',
#  'Postal Code': 91104,
#  'Product ID': 'OFF-ST-10003656',
#  'Product Name': 'Safco Industrial Wire Shelving',
#  'Profit': 20.1579,
#  'Quantity': 7,
#  'Region': 'West',
#  'Row ID': 146,
#  'Sales': 671.93,
#  'Segment': 'Consumer',
#  'Ship Date': '09-12-2015',
#  'Ship Mode': 'Standard Class',
#  'State': 'California',
#  'Sub-Category': 'Storage',
#  '_id': ObjectId('67adea81fe577b36e55684ea')}
# {'Category': 'Office Supplies',
#  'City': 'Scottsdale',
#  'Country': 'United States',
#  'Customer ID': 'TW-21025',
#  'Customer Name': 'Tamara Willingham',
#  'Discount': 0.2,
#  'Order Date': '3/13/2016',
#  'Order ID': 'CA-2016-158834',
#  'Postal Code': 85254,
#  'Product ID': 'OFF-AP-10000326',
#  'Product Name': 'Belkin 7 Outlet SurgeMaster Surge Protector with Phone '
#                  'Protection',
#  'Profit': 17.766,
#  'Quantity': 5,
#  'Region': 'West',
#  'Row ID': 152,
#  'Sales': 157.92,
#  'Segment': 'Home Office',
#  'Ship Date': '3/16/2016',
#  'Ship Mode': 'Premium Class',
#  'State': 'Arizona',
#  'Sub-Category': 'Appliances',
#  '_id': ObjectId('67adea81fe577b36e55684f0')}
# {'Category': 'Technology',
#  'City': 'Scottsdale',
#  'Country': 'United States',
#  'Customer ID': 'TW-21025',
#  'Customer Name': 'Tamara Willingham',
#  'Discount': 0.2,
#  'Order Date': '3/13/2016',
#  'Order ID': 'CA-2016-158834',
#  'Postal Code': 85254,
#  'Product ID': 'TEC-PH-10001254',
#  'Product Name': 'Jabra BIZ 2300 Duo QD Duo Corded\xa0Headset',
#  'Profit': 15.2388,
#  'Quantity': 2,
#  'Region': 'West',
#  'Row ID': 153,
#  'Sales': 203.184,
#  'Segment': 'Home Office',
#  'Ship Date': '3/16/2016',
#  'Ship Mode': 'Premium Class',
#  'State': 'Arizona',
#  'Sub-Category': 'Phones',
#  '_id': ObjectId('67adea81fe577b36e55684f1')}
# {'Category': 'Office Supplies',
#  'City': 'San Jose',
#  'Country': 'United States',
#  'Customer ID': 'SP-20650',
#  'Customer Name': 'Stephanie Phelps',
#  'Discount': 0.0,
#  'Order Date': '5/31/2015',
#  'Order ID': 'CA-2015-124919',
#  'Postal Code': 95123,
#  'Product ID': 'OFF-PA-10001950',
#  'Product Name': 'Southworth 25% Cotton Antique Laid Paper & Envelopes',
#  'Profit': 26.271,
#  'Quantity': 7,
#  'Region': 'West',
#  'Row ID': 154,
#  'Sales': 58.38,
#  'Segment': 'Corporate',
#  'Ship Date': '06-02-2015',
#  'Ship Mode': 'Premium Class',
#  'State': 'California',
#  'Sub-Category': 'Paper',
#  '_id': ObjectId('67adea81fe577b36e55684f2')}
# {'Category': 'Office Supplies',
#  'City': 'San Jose',
#  'Country': 'United States',
#  'Customer ID': 'SP-20650',
#  'Customer Name': 'Stephanie Phelps',
#  'Discount': 0.0,
#  'Order Date': '5/31/2015',
#  'Order ID': 'CA-2015-124919',
#  'Postal Code': 95123,
#  'Product ID': 'OFF-PA-10002254',
#  'Product Name': 'Xerox 1883',
#  'Profit': 48.5392,
#  'Quantity': 4,
#  'Region': 'West',
#  'Row ID': 155,
#  'Sales': 105.52,
#  'Segment': 'Corporate',
#  'Ship Date': '06-02-2015',
#  'Ship Mode': 'Premium Class',
#  'State': 'California',
#  'Sub-Category': 'Paper',
#  '_id': ObjectId('67adea81fe577b36e55684f3')}
# {'Category': 'Office Supplies',
#  'City': 'San Jose',
#  'Country': 'United States',
#  'Customer ID': 'SP-20650',
#  'Customer Name': 'Stephanie Phelps',
#  'Discount': 0.0,
#  'Order Date': '5/31/2015',
#  'Order ID': 'CA-2015-124919',
#  'Postal Code': 95123,
#  'Product ID': 'OFF-ST-10001590',
#  'Product Name': 'Tenex Personal Project File with Scoop Front Design, Black',
#  'Profit': 21.0288,
#  'Quantity': 6,
#  'Region': 'West',
#  'Row ID': 156,
#  'Sales': 80.88,
#  'Segment': 'Corporate',
#  'Ship Date': '06-02-2015',
#  'Ship Mode': 'Premium Class',
#  'State': 'California',
#  'Sub-Category': 'Storage',
#  '_id': ObjectId('67adea81fe577b36e55684f4')}
# {'Category': 'Furniture',
#  'City': 'Seattle',
#  'Country': 'United States',
#  'Customer ID': 'DB-13060',
#  'Customer Name': 'Dave Brooks',
#  'Discount': 0.2,
#  'Order Date': '03-01-2014',
#  'Order ID': 'CA-2014-104269',
#  'Postal Code': 98115,
#  'Product ID': 'FUR-CH-10004063',
#  'Product Name': "Global Deluxe High-Back Manager's Chair",
#  'Profit': 51.4764,
#  'Quantity': 2,
#  'Region': 'West',
#  'Row ID': 158,
#  'Sales': 457.568,
#  'Segment': 'Consumer',
#  'Ship Date': '03-06-2014',
#  'Ship Mode': 'Second Class',
#  'State': 'Washington',
#  'Sub-Category': 'Chairs',
#  '_id': ObjectId('67adea81fe577b36e55684f6')}
# {'Category': 'Office Supplies',
#  'City': 'Los Angeles',
#  'Country': 'United States',
#  'Customer ID': 'CS-12130',
#  'Customer Name': 'Chad Sievert',
#  'Discount': 0.0,
#  'Order Date': '08-05-2014',
#  'Order ID': 'CA-2014-118962',
#  'Postal Code': 90004,
#  'Product ID': 'OFF-PA-10001144',
#  'Product Name': 'Xerox 1913',
#  'Profit': 53.2608,
#  'Quantity': 2,
#  'Region': 'West',
#  'Row ID': 173,
#  'Sales': 110.96,
#  'Segment': 'Consumer',
#  'Ship Date': '08-09-2014',
#  'Ship Mode': 'Standard Class',
#  'State': 'California',
#  'Sub-Category': 'Paper',
#  '_id': ObjectId('67adea81fe577b36e5568505')}
# {'Category': 'Furniture',
#  'City': 'Los Angeles',
#  'Country': 'United States',
#  'Customer ID': 'CS-12130',
#  'Customer Name': 'Chad Sievert',
#  'Discount': 0.2,
#  'Order Date': '08-05-2014',
#  'Order ID': 'CA-2014-118962',
#  'Postal Code': 90004,
#  'Product ID': 'FUR-CH-10003817',
#  'Product Name': 'Global Value Steno Chair, Gray',
#  'Profit': 21.259,
#  'Quantity': 7,
#  'Region': 'West',
#  'Row ID': 174,
#  'Sales': 340.144,
#  'Segment': 'Consumer',
#  'Ship Date': '08-09-2014',
#  'Ship Mode': 'Standard Class',
#  'State': 'California',
#  'Sub-Category': 'Chairs',
#  '_id': ObjectId('67adea81fe577b36e5568506')}
# {'Category': 'Technology',
#  'City': 'Los Angeles',
#  'Country': 'United States',
#  'Customer ID': 'FM-14290',
#  'Customer Name': 'Frank Merwin',
#  'Discount': 0.0,
#  'Order Date': '8/26/2014',
#  'Order ID': 'CA-2014-123260',
#  'Postal Code': 90032,
#  'Product ID': 'TEC-AC-10002323',
#  'Product Name': 'SanDisk Ultra 32 GB MicroSDHC Class 10 Memory Card',
#  'Profit': 22.984,
#  'Quantity': 8,
#  'Region': 'West',
#  'Row ID': 187,
#  'Sales': 176.8,
#  'Segment': 'Home Office',
#  'Ship Date': '8/30/2014',
#  'Ship Mode': 'Standard Class',
#  'State': 'California',
#  'Sub-Category': 'Accessories',
#  '_id': ObjectId('67adea81fe577b36e5568513')}
# {'Category': 'Furniture',
#  'City': 'Denver',
#  'Country': 'United States',
#  'Customer ID': 'BS-11755',
#  'Customer Name': 'Bruce Stewart',
#  'Discount': 0.5,
#  'Order Date': '08-03-2014',
#  'Order ID': 'CA-2014-133690',
#  'Postal Code': 80219,
#  'Product ID': 'FUR-TA-10004289',
#  'Product Name': 'BoxOffice By Design Rectangular and Half-Moon Meeting Room '
#                  'Tables',
#  'Profit': -161.875,
#  'Quantity': 2,
#  'Region': 'West',
#  'Row ID': 202,
#  'Sales': 218.75,
#  'Segment': 'Consumer',
#  'Ship Date': '08-05-2014',
#  'Ship Mode': 'Premium Class',
#  'State': 'Colorado',
#  'Sub-Category': 'Tables',
#  '_id': ObjectId('67adea81fe577b36e5568522')}
# {'Category': 'Technology',
#  'City': 'Whittier',
#  'Country': 'United States',
#  'Customer ID': 'LE-16810',
#  'Customer Name': 'Laurel Elliston',
#  'Discount': 0.2,
#  'Order Date': '12-09-2017',
#  'Order ID': 'CA-2017-108329',
#  'Postal Code': 90604,
#  'Product ID': 'TEC-PH-10001918',
#  'Product Name': 'Nortel Business Series Terminal T7208 Digital phone',
#  'Profit': 44.4768,
#  'Quantity': 4,
#  'Region': 'West',
#  'Row ID': 206,
#  'Sales': 444.768,
#  'Segment': 'Consumer',
#  'Ship Date': '12/14/2017',
#  'Ship Mode': 'Standard Class',
#  'State': 'California',
#  'Sub-Category': 'Phones',
#  '_id': ObjectId('67adea81fe577b36e5568526')}
# {'Category': 'Office Supplies',
#  'City': 'Los Angeles',
#  'Country': 'United States',
#  'Customer ID': 'JH-15910',
#  'Customer Name': 'Jonathan Howell',
#  'Discount': 0.0,
#  'Order Date': '10/28/2016',
#  'Order ID': 'CA-2016-130162',
#  'Postal Code': 90032,
#  'Product ID': 'OFF-ST-10001328',
#  'Product Name': 'Personal Filing Tote with Lid, Black/Gray',
#  'Profit': 26.0568,
#  'Quantity': 6,
#  'Region': 'West',
#  'Row ID': 218,
#  'Sales': 93.06,
#  'Segment': 'Consumer',
#  'Ship Date': '11-01-2016',
#  'Ship Mode': 'Standard Class',
#  'State': 'California',
#  'Sub-Category': 'Storage',
#  '_id': ObjectId('67adea81fe577b36e5568532')}
# {'Category': 'Technology',
#  'City': 'Los Angeles',
#  'Country': 'United States',
#  'Customer ID': 'JH-15910',
#  'Customer Name': 'Jonathan Howell',
#  'Discount': 0.2,
#  'Order Date': '10/28/2016',
#  'Order ID': 'CA-2016-130162',
#  'Postal Code': 90032,
#  'Product ID': 'TEC-PH-10002563',
#  'Product Name': 'Adtran 1202752G1',
#  'Profit': 22.6782,
#  'Quantity': 3,
#  'Region': 'West',
#  'Row ID': 219,
#  'Sales': 302.376,
#  'Segment': 'Consumer',
#  'Ship Date': '11-01-2016',
#  'Ship Mode': 'Standard Class',
#  'State': 'California',
#  'Sub-Category': 'Phones',
#  '_id': ObjectId('67adea81fe577b36e5568533')}
# {'Category': 'Furniture',
#  'City': 'San Francisco',
#  'Country': 'United States',
#  'Customer ID': 'LH-17155',
#  'Customer Name': 'Logan Haushalter',
#  'Discount': 0.2,
#  'Order Date': '12-10-2016',
#  'Order ID': 'CA-2016-154739',
#  'Postal Code': 94109,
#  'Product ID': 'FUR-CH-10002965',
#  'Product Name': 'Global Leather Highback Executive Chair with Pneumatic '
#                  'Height Adjustment, Black',
#  'Profit': 28.1372,
#  'Quantity': 2,
#  'Region': 'West',
#  'Row ID': 250,
#  'Sales': 321.568,
#  'Segment': 'Consumer',
#  'Ship Date': '12/15/2016',
#  'Ship Mode': 'Second Class',
#  'State': 'California',
#  'Sub-Category': 'Chairs',
#  '_id': ObjectId('67adea81fe577b36e5568552')}
# {'Category': 'Technology',
#  'City': 'San Diego',
#  'Country': 'United States',
#  'Customer ID': 'KC-16540',
#  'Customer Name': 'Kelly Collister',
#  'Discount': 0.0,
#  'Order Date': '09-11-2016',
#  'Order ID': 'CA-2016-145625',
#  'Postal Code': 92037,
#  'Product ID': 'TEC-AC-10003832',
#  'Product Name': 'Logitech\xa0P710e Mobile Speakerphone',
#  'Profit': 636.0003,
#  'Quantity': 13,
#  'Region': 'West',
#  'Row ID': 252,
#  'Sales': 3347.37,
#  'Segment': 'Consumer',
#  'Ship Date': '9/17/2016',
#  'Ship Mode': 'Standard Class',
#  'State': 'California',
#  'Sub-Category': 'Accessories',
#  '_id': ObjectId('67adea81fe577b36e5568554')}
# {'Category': 'Technology',
#  'City': 'Brentwood',
#  'Country': 'United States',
#  'Customer ID': 'AH-10210',
#  'Customer Name': 'Alan Hwang',
#  'Discount': 0.0,
#  'Order Date': '11-10-2015',
#  'Order ID': 'CA-2015-155040',
#  'Postal Code': 94513,
#  'Product ID': 'TEC-AC-10004469',
#  'Product Name': 'Microsoft Sculpt Comfort Mouse',
#  'Profit': 35.156,
#  'Quantity': 2,
#  'Region': 'West',
#  'Row ID': 266,
#  'Sales': 79.9,
#  'Segment': 'Consumer',
#  'Ship Date': '11/15/2015',
#  'Ship Mode': 'Standard Class',
#  'State': 'California',
#  'Sub-Category': 'Accessories',
#  '_id': ObjectId('67adea81fe577b36e5568562')}
# {'Category': 'Office Supplies',
#  'City': 'San Francisco',
#  'Country': 'United States',
#  'Customer ID': 'KH-16690',
#  'Customer Name': 'Kristen Hastings',
#  'Discount': 0.0,
#  'Order Date': '12/28/2017',
#  'Order ID': 'CA-2017-163979',
#  'Postal Code': 94110,
#  'Product ID': 'OFF-ST-10003208',
#  'Product Name': 'Adjustable Depth Letter/Legal Cart',
#  'Profit': 210.4936,
#  'Quantity': 4,
#  'Region': 'West',
#  'Row ID': 271,
#  'Sales': 725.84,
#  'Segment': 'Corporate',
#  'Ship Date': '01-02-2018',
#  'Ship Mode': 'Second Class',
#  'State': 'California',
#  'Sub-Category': 'Storage',
#  '_id': ObjectId('67adea81fe577b36e5568567')}
# {'Category': 'Technology',
#  'City': 'San Francisco',
#  'Country': 'United States',
#  'Customer ID': 'HA-14920',
#  'Customer Name': 'Helen Andreada',
#  'Discount': 0.0,
#  'Order Date': '7/30/2015',
#  'Order ID': 'CA-2015-155334',
#  'Postal Code': 94109,
#  'Product ID': 'TEC-AC-10003628',
#  'Product Name': 'Logitech 910-002974 M325 Wireless Mouse for Web Scrolling',
#  'Profit': 92.3692,
#  'Quantity': 7,
#  'Region': 'West',
#  'Row ID': 272,
#  'Sales': 209.93,
#  'Segment': 'Consumer',
#  'Ship Date': '7/31/2015',
#  'Ship Mode': 'Premium Class',
#  'State': 'California',
#  'Sub-Category': 'Accessories',
#  '_id': ObjectId('67adea81fe577b36e5568568')}
# {'Category': 'Furniture',
#  'City': 'Los Angeles',
#  'Country': 'United States',
#  'Customer ID': 'JO-15280',
#  'Customer Name': "Jas O'Carroll",
#  'Discount': 0.2,
#  'Order Date': '11-02-2015',
#  'Order ID': 'CA-2015-130890',
#  'Postal Code': 90004,
#  'Product ID': 'FUR-TA-10002903',
#  'Product Name': 'Bevis Round Bullnose 29" High Table Top',
#  'Profit': 51.942,
#  'Quantity': 5,
#  'Region': 'West',
#  'Row ID': 283,
#  'Sales': 1038.84,
#  'Segment': 'Consumer',
#  'Ship Date': '11-06-2015',
#  'Ship Mode': 'Standard Class',
#  'State': 'California',
#  'Sub-Category': 'Tables',
#  '_id': ObjectId('67adea81fe577b36e5568573')}
# {'Category': 'Office Supplies',
#  'City': 'Portland',
#  'Country': 'United States',
#  'Customer ID': 'TB-21520',
#  'Customer Name': 'Tracy Blumstein',
#  'Discount': 0.2,
#  'Order Date': '9/26/2015',
#  'Order ID': 'CA-2015-130883',
#  'Postal Code': 97206,
#  'Product ID': 'OFF-PA-10000474',
#  'Product Name': 'Easy-staple paper',
#  'Profit': 47.844,
#  'Quantity': 5,
#  'Region': 'West',
#  'Row ID': 284,
#  'Sales': 141.76,
#  'Segment': 'Consumer',
#  'Ship Date': '10-02-2015',
#  'Ship Mode': 'Standard Class',
#  'State': 'Oregon',
#  'Sub-Category': 'Paper',
#  '_id': ObjectId('67adea81fe577b36e5568574')}
# {'Category': 'Technology',
#  'City': 'Portland',
#  'Country': 'United States',
#  'Customer ID': 'TB-21520',
#  'Customer Name': 'Tracy Blumstein',
#  'Discount': 0.2,
#  'Order Date': '9/26/2015',
#  'Order ID': 'CA-2015-130883',
#  'Postal Code': 97206,
#  'Product ID': 'TEC-AC-10001956',
#  'Product Name': 'Microsoft Arc Touch Mouse',
#  'Profit': 47.96,
#  'Quantity': 5,
#  'Region': 'West',
#  'Row ID': 285,
#  'Sales': 239.8,
#  'Segment': 'Consumer',
#  'Ship Date': '10-02-2015',
#  'Ship Mode': 'Standard Class',
#  'State': 'Oregon',
#  'Sub-Category': 'Accessories',
#  '_id': ObjectId('67adea81fe577b36e5568575')}
# {'Category': 'Furniture',
#  'City': 'Colorado Springs',
#  'Country': 'United States',
#  'Customer ID': 'KL-16555',
#  'Customer Name': 'Kelly Lampkin',
#  'Discount': 0.2,
#  'Order Date': '12/26/2014',
#  'Order ID': 'CA-2014-111451',
#  'Postal Code': 80906,
#  'Product ID': 'FUR-FU-10004091',
#  'Product Name': 'Howard Miller 13" Diameter Goldtone Round Wall Clock',
#  'Profit': 78.8592,
#  'Quantity': 8,
#  'Region': 'West',
#  'Row ID': 294,
#  'Sales': 300.416,
#  'Segment': 'Corporate',
#  'Ship Date': '12/28/2014',
#  'Ship Mode': 'Premium Class',
#  'State': 'Colorado',
#  'Sub-Category': 'Furnishings',
#  '_id': ObjectId('67adea81fe577b36e556857e')}
# {'Category': 'Furniture',
#  'City': 'Colorado Springs',
#  'Country': 'United States',
#  'Customer ID': 'KL-16555',
#  'Customer Name': 'Kelly Lampkin',
#  'Discount': 0.2,
#  'Order Date': '12/26/2014',
#  'Order ID': 'CA-2014-111451',
#  'Postal Code': 80906,
#  'Product ID': 'FUR-CH-10001891',
#  'Product Name': 'Global Deluxe Office Fabric Chairs',
#  'Profit': 20.1558,
#  'Quantity': 3,
#  'Region': 'West',
#  'Row ID': 295,
#  'Sales': 230.352,
#  'Segment': 'Corporate',
#  'Ship Date': '12/28/2014',
#  'Ship Mode': 'Premium Class',
#  'State': 'Colorado',
#  'Sub-Category': 'Chairs',
#  '_id': ObjectId('67adea81fe577b36e556857f')}
# {'Category': 'Furniture',
#  'City': 'Colorado Springs',
#  'Country': 'United States',
#  'Customer ID': 'KL-16555',
#  'Customer Name': 'Kelly Lampkin',
#  'Discount': 0.2,
#  'Order Date': '12/26/2014',
#  'Order ID': 'CA-2014-111451',
#  'Postal Code': 80906,
#  'Product ID': 'FUR-FU-10002918',
#  'Product Name': 'Eldon ClusterMat Chair Mat with Cordless Antistatic '
#                  'Protection',
#  'Profit': -24.5646,
#  'Quantity': 3,
#  'Region': 'West',
#  'Row ID': 296,
#  'Sales': 218.352,
#  'Segment': 'Corporate',
#  'Ship Date': '12/28/2014',
#  'Ship Mode': 'Premium Class',
#  'State': 'Colorado',
#  'Sub-Category': 'Furnishings',
#  '_id': ObjectId('67adea81fe577b36e5568580')}
# {'Category': 'Office Supplies',
#  'City': 'Colorado Springs',
#  'Country': 'United States',
#  'Customer ID': 'KL-16555',
#  'Customer Name': 'Kelly Lampkin',
#  'Discount': 0.7,
#  'Order Date': '12/26/2014',
#  'Order ID': 'CA-2014-111451',
#  'Postal Code': 80906,
#  'Product ID': 'OFF-BI-10004593',
#  'Product Name': 'Ibico Laser Imprintable Binding System Covers',
#  'Profit': -62.88,
#  'Quantity': 5,
#  'Region': 'West',
#  'Row ID': 297,
#  'Sales': 78.6,
#  'Segment': 'Corporate',
#  'Ship Date': '12/28/2014',
#  'Ship Mode': 'Premium Class',
#  'State': 'Colorado',
#  'Sub-Category': 'Binders',
#  '_id': ObjectId('67adea81fe577b36e5568581')}
# {'Category': 'Furniture',
#  'City': 'Arvada',
#  'Country': 'United States',
#  'Customer ID': 'BP-11185',
#  'Customer Name': 'Ben Peterman',
#  'Discount': 0.2,
#  'Order Date': '09-12-2016',
#  'Order ID': 'CA-2016-142902',
#  'Postal Code': 80004,
#  'Product ID': 'FUR-CH-10004086',
#  'Product Name': 'Hon 4070 Series Pagoda Armless Upholstered Stacking Chairs',
#  'Profit': 52.5114,
#  'Quantity': 2,
#  'Region': 'West',
#  'Row ID': 311,
#  'Sales': 466.768,
#  'Segment': 'Corporate',
#  'Ship Date': '9/14/2016',
#  'Ship Mode': 'Second Class',
#  'State': 'Colorado',
#  'Sub-Category': 'Chairs',
#  '_id': ObjectId('67adea81fe577b36e556858f')}
# {'Category': 'Office Supplies',
#  'City': 'Hesperia',
#  'Country': 'United States',
#  'Customer ID': 'GK-14620',
#  'Customer Name': 'Grace Kelly',
#  'Discount': 0.2,
#  'Order Date': '4/23/2016',
#  'Order ID': 'CA-2016-162138',
#  'Postal Code': 92345,
#  'Product ID': 'OFF-BI-10004593',
#  'Product Name': 'Ibico Laser Imprintable Binding System Covers',
#  'Profit': 81.744,
#  'Quantity': 6,
#  'Region': 'West',
#  'Row ID': 324,
#  'Sales': 251.52,
#  'Segment': 'Corporate',
#  'Ship Date': '4/27/2016',
#  'Ship Mode': 'Standard Class',
#  'State': 'California',
#  'Sub-Category': 'Binders',
#  '_id': ObjectId('67adea81fe577b36e556859c')}
# {'Category': 'Technology',
#  'City': 'Hesperia',
#  'Country': 'United States',
#  'Customer ID': 'GK-14620',
#  'Customer Name': 'Grace Kelly',
#  'Discount': 0.0,
#  'Order Date': '4/23/2016',
#  'Order ID': 'CA-2016-162138',
#  'Postal Code': 92345,
#  'Product ID': 'TEC-AC-10001908',
#  'Product Name': 'Logitech Wireless Headset h800',
#  'Profit': 34.9965,
#  'Quantity': 1,
#  'Region': 'West',
#  'Row ID': 325,
#  'Sales': 99.99,
#  'Segment': 'Corporate',
#  'Ship Date': '4/27/2016',
#  'Ship Mode': 'Standard Class',
#  'State': 'California',
#  'Sub-Category': 'Accessories',
#  '_id': ObjectId('67adea81fe577b36e556859d')}
# {'Category': 'Technology',
#  'City': 'Los Angeles',
#  'Country': 'United States',
#  'Customer ID': 'DB-13615',
#  'Customer Name': 'Doug Bickford',
#  'Discount': 0.2,
#  'Order Date': '09-01-2015',
#  'Order ID': 'CA-2015-137946',
#  'Postal Code': 90045,
#  'Product ID': 'TEC-CO-10001449',
#  'Product Name': 'Hewlett Packard LaserJet 3310 Copier',
#  'Profit': 335.9944,
#  'Quantity': 2,
#  'Region': 'West',
#  'Row ID': 336,
#  'Sales': 959.984,
#  'Segment': 'Consumer',
#  'Ship Date': '09-04-2015',
#  'Ship Mode': 'Second Class',
#  'State': 'California',
#  'Sub-Category': 'Copiers',
#  '_id': ObjectId('67adea81fe577b36e55685a8')}
# {'Category': 'Furniture',
#  'City': 'San Francisco',
#  'Country': 'United States',
#  'Customer ID': 'AC-10420',
#  'Customer Name': 'Alyssa Crouse',
#  'Discount': 0.2,
#  'Order Date': '07-12-2014',
#  'Order ID': 'CA-2014-129924',
#  'Postal Code': 94122,
#  'Product ID': 'FUR-TA-10004575',
#  'Product Name': 'Hon 5100 Series Wood Tables',
#  'Profit': -17.4588,
#  'Quantity': 3,
#  'Region': 'West',
#  'Row ID': 339,
#  'Sales': 698.352,
#  'Segment': 'Corporate',
#  'Ship Date': '7/17/2014',
#  'Ship Mode': 'Standard Class',
#  'State': 'California',
#  'Sub-Category': 'Tables',
#  '_id': ObjectId('67adea81fe577b36e55685ab')}
# {'Category': 'Office Supplies',
#  'City': 'San Francisco',
#  'Country': 'United States',
#  'Customer ID': 'JD-16060',
#  'Customer Name': 'Julia Dunbar',
#  'Discount': 0.0,
#  'Order Date': '9/24/2014',
#  'Order ID': 'CA-2014-123344',
#  'Postal Code': 94109,
#  'Product ID': 'OFF-ST-10001713',
#  'Product Name': 'Gould Plastics 9-Pocket Panel Bin, 18-3/8w x 5-1/4d x '
#                  '20-1/2h, Black',
#  'Profit': 8.4784,
#  'Quantity': 4,
#  'Region': 'West',
#  'Row ID': 366,
#  'Sales': 211.96,
#  'Segment': 'Consumer',
#  'Ship Date': '9/29/2014',
#  'Ship Mode': 'Standard Class',
#  'State': 'California',
#  'Sub-Category': 'Storage',
#  '_id': ObjectId('67adea81fe577b36e55685c6')}
# {'Category': 'Technology',
#  'City': 'Tucson',
#  'Country': 'United States',
#  'Customer ID': 'AG-10900',
#  'Customer Name': 'Arthur Gainer',
#  'Discount': 0.2,
#  'Order Date': '7/23/2014',
#  'Order ID': 'US-2014-119137',
#  'Postal Code': 85705,
#  'Product ID': 'TEC-AC-10003911',
#  'Product Name': 'NETGEAR AC1750 Dual Band Gigabit\xa0Smart WiFi Router',
#  'Profit': 179.1888,
#  'Quantity': 8,
#  'Region': 'West',
#  'Row ID': 374,
#  'Sales': 1023.936,
#  'Segment': 'Consumer',
#  'Ship Date': '7/27/2014',
#  'Ship Mode': 'Standard Class',
#  'State': 'Arizona',
#  'Sub-Category': 'Accessories',
#  '_id': ObjectId('67adea81fe577b36e55685ce')}
# {'Category': 'Technology',
#  'City': 'Tucson',
#  'Country': 'United States',
#  'Customer ID': 'AG-10900',
#  'Customer Name': 'Arthur Gainer',
#  'Discount': 0.2,
#  'Order Date': '7/23/2014',
#  'Order ID': 'US-2014-119137',
#  'Postal Code': 85705,
#  'Product ID': 'TEC-AC-10002076',
#  'Product Name': 'Microsoft Natural Keyboard Elite',
#  'Profit': -29.94,
#  'Quantity': 10,
#  'Region': 'West',
#  'Row ID': 376,
#  'Sales': 479.04,
#  'Segment': 'Consumer',
#  'Ship Date': '7/27/2014',
#  'Ship Mode': 'Standard Class',
#  'State': 'Arizona',
#  'Sub-Category': 'Accessories',
#  '_id': ObjectId('67adea81fe577b36e55685d0')}
# {'Category': 'Office Supplies',
#  'City': 'San Francisco',
#  'Country': 'United States',
#  'Customer ID': 'AS-10285',
#  'Customer Name': 'Alejandro Savely',
#  'Discount': 0.0,
#  'Order Date': '10/28/2016',
#  'Order ID': 'CA-2016-134775',
#  'Postal Code': 94109,
#  'Product ID': 'OFF-PA-10004734',
#  'Product Name': 'Southworth Structures Collection',
#  'Profit': 25.48,
#  'Quantity': 7,
#  'Region': 'West',
#  'Row ID': 382,
#  'Sales': 50.96,
#  'Segment': 'Corporate',
#  'Ship Date': '10/29/2016',
#  'Ship Mode': 'Premium Class',
#  'State': 'California',
#  'Sub-Category': 'Paper',
#  '_id': ObjectId('67adea81fe577b36e55685d6')}
# {'Category': 'Technology',
#  'City': 'Des Moines',
#  'Country': 'United States',
#  'Customer ID': 'JG-15115',
#  'Customer Name': 'Jack Garza',
#  'Discount': 0.2,
#  'Order Date': '9/21/2014',
#  'Order ID': 'US-2014-135972',
#  'Postal Code': 98198,
#  'Product ID': 'TEC-PH-10003012',
#  'Product Name': 'Nortel Meridian M3904 Professional Digital phone',
#  'Profit': 27.7182,
#  'Quantity': 2,
#  'Region': 'West',
#  'Row ID': 392,
#  'Sales': 246.384,
#  'Segment': 'Consumer',
#  'Ship Date': '9/23/2014',
#  'Ship Mode': 'Second Class',
#  'State': 'Washington',
#  'Sub-Category': 'Phones',
#  '_id': ObjectId('67adea81fe577b36e55685e0')}
# {'Category': 'Technology',
#  'City': 'Des Moines',
#  'Country': 'United States',
#  'Customer ID': 'JG-15115',
#  'Customer Name': 'Jack Garza',
#  'Discount': 0.0,
#  'Order Date': '9/21/2014',
#  'Order ID': 'US-2014-135972',
#  'Postal Code': 98198,
#  'Product ID': 'TEC-CO-10002313',
#  'Product Name': 'Canon PC1080F Personal Copier',
#  'Profit': 701.9883,
#  'Quantity': 3,
#  'Region': 'West',
#  'Row ID': 393,
#  'Sales': 1799.97,
#  'Segment': 'Consumer',
#  'Ship Date': '9/23/2014',
#  'Ship Mode': 'Second Class',
#  'State': 'Washington',
#  'Sub-Category': 'Copiers',
#  '_id': ObjectId('67adea81fe577b36e55685e1')}
# {'Category': 'Office Supplies',
#  'City': 'Las Vegas',
#  'Country': 'United States',
#  'Customer ID': 'VP-21730',
#  'Customer Name': 'Victor Preis',
#  'Discount': 0.2,
#  'Order Date': '6/30/2017',
#  'Order ID': 'CA-2017-102946',
#  'Postal Code': 89115,
#  'Product ID': 'OFF-BI-10004492',
#  'Product Name': 'Tuf-Vin Binders',
#  'Profit': 25.5798,
#  'Quantity': 3,
#  'Region': 'West',
#  'Row ID': 395,
#  'Sales': 75.792,
#  'Segment': 'Home Office',
#  'Ship Date': '07-05-2017',
#  'Ship Mode': 'Standard Class',
#  'State': 'Nevada',
#  'Sub-Category': 'Binders',
#  '_id': ObjectId('67adea81fe577b36e55685e3')}
# {'Category': 'Technology',
#  'City': 'San Francisco',
#  'Country': 'United States',
#  'Customer ID': 'KH-16510',
#  'Customer Name': 'Keith Herrera',
#  'Discount': 0.0,
#  'Order Date': '12-08-2017',
#  'Order ID': 'CA-2017-117457',
#  'Postal Code': 94110,
#  'Product ID': 'TEC-AC-10000158',
#  'Product Name': 'Sony 64GB Class 10 Micro SDHC R40 Memory Card',
#  'Profit': 37.7895,
#  'Quantity': 5,
#  'Region': 'West',
#  'Row ID': 406,
#  'Sales': 179.95,
#  'Segment': 'Consumer',
#  'Ship Date': '12-12-2017',
#  'Ship Mode': 'Standard Class',
#  'State': 'California',
#  'Sub-Category': 'Accessories',
#  '_id': ObjectId('67adea81fe577b36e55685ee')}
# {'Category': 'Technology',
#  'City': 'San Francisco',
#  'Country': 'United States',
#  'Customer ID': 'KH-16510',
#  'Customer Name': 'Keith Herrera',
#  'Discount': 0.2,
#  'Order Date': '12-08-2017',
#  'Order ID': 'CA-2017-117457',
#  'Postal Code': 94110,
#  'Product ID': 'TEC-CO-10004115',
#  'Product Name': 'Sharp AL-1530CS Digital Copier',
#  'Profit': 434.9913,
#  'Quantity': 3,
#  'Region': 'West',
#  'Row ID': 407,
#  'Sales': 1199.976,
#  'Segment': 'Consumer',
#  'Ship Date': '12-12-2017',
#  'Ship Mode': 'Standard Class',
#  'State': 'California',
#  'Sub-Category': 'Copiers',
#  '_id': ObjectId('67adea81fe577b36e55685ef')}
# {'Category': 'Furniture',
#  'City': 'San Francisco',
#  'Country': 'United States',
#  'Customer ID': 'KH-16510',
#  'Customer Name': 'Keith Herrera',
#  'Discount': 0.2,
#  'Order Date': '12-08-2017',
#  'Order ID': 'CA-2017-117457',
#  'Postal Code': 94110,
#  'Product ID': 'FUR-TA-10002041',
#  'Product Name': 'Bevis Round Conference Table Top, X-Base',
#  'Profit': -112.9527,
#  'Quantity': 7,
#  'Region': 'West',
#  'Row ID': 409,
#  'Sales': 1004.024,
#  'Segment': 'Consumer',
#  'Ship Date': '12-12-2017',
#  'Ship Mode': 'Standard Class',
#  'State': 'California',
#  'Sub-Category': 'Tables',
#  '_id': ObjectId('67adea81fe577b36e55685f1')}
# {'Category': 'Office Supplies',
#  'City': 'San Francisco',
#  'Country': 'United States',
#  'Customer ID': 'KH-16510',
#  'Customer Name': 'Keith Herrera',
#  'Discount': 0.0,
#  'Order Date': '12-08-2017',
#  'Order ID': 'CA-2017-117457',
#  'Postal Code': 94110,
#  'Product ID': 'OFF-PA-10001970',
#  'Product Name': 'Xerox 1908',
#  'Profit': 27.4302,
#  'Quantity': 1,
#  'Region': 'West',
#  'Row ID': 412,
#  'Sales': 55.98,
#  'Segment': 'Consumer',
#  'Ship Date': '12-12-2017',
#  'Ship Mode': 'Standard Class',
#  'State': 'California',
#  'Sub-Category': 'Paper',
#  '_id': ObjectId('67adea81fe577b36e55685f4')}
# {'Category': 'Furniture',
#  'City': 'San Francisco',
#  'Country': 'United States',
#  'Customer ID': 'KH-16510',
#  'Customer Name': 'Keith Herrera',
#  'Discount': 0.15,
#  'Order Date': '12-08-2017',
#  'Order ID': 'CA-2017-117457',
#  'Postal Code': 94110,
#  'Product ID': 'FUR-BO-10001972',
#  'Product Name': "O'Sullivan 4-Shelf Bookcase in Odessa Pine",
#  'Profit': 31.4548,
#  'Quantity': 13,
#  'Region': 'West',
#  'Row ID': 413,
#  'Sales': 1336.829,
#  'Segment': 'Consumer',
#  'Ship Date': '12-12-2017',
#  'Ship Mode': 'Standard Class',
#  'State': 'California',
#  'Sub-Category': 'Bookcases',
#  '_id': ObjectId('67adea81fe577b36e55685f5')}
# {'Category': 'Furniture',
#  'City': 'San Francisco',
#  'Country': 'United States',
#  'Customer ID': 'KH-16510',
#  'Customer Name': 'Keith Herrera',
#  'Discount': 0.2,
#  'Order Date': '12-08-2017',
#  'Order ID': 'CA-2017-117457',
#  'Postal Code': 94110,
#  'Product ID': 'FUR-CH-10003956',
#  'Product Name': 'Novimex High-Tech Fabric Mesh Task Chair',
#  'Profit': -18.4548,
#  'Quantity': 2,
#  'Region': 'West',
#  'Row ID': 414,
#  'Sales': 113.568,
#  'Segment': 'Consumer',
#  'Ship Date': '12-12-2017',
#  'Ship Mode': 'Standard Class',
#  'State': 'California',
#  'Sub-Category': 'Chairs',
#  '_id': ObjectId('67adea81fe577b36e55685f6')}
# {'Category': 'Office Supplies',
#  'City': 'Seattle',
#  'Country': 'United States',
#  'Customer ID': 'KC-16675',
#  'Customer Name': 'Kimberly Carter',
#  'Discount': 0.0,
#  'Order Date': '11-03-2017',
#  'Order ID': 'CA-2017-142636',
#  'Postal Code': 98105,
#  'Product ID': 'OFF-PA-10000157',
#  'Product Name': 'Xerox 191',
#  'Profit': 65.7342,
#  'Quantity': 7,
#  'Region': 'West',
#  'Row ID': 415,
#  'Sales': 139.86,
#  'Segment': 'Corporate',
#  'Ship Date': '11-07-2017',
#  'Ship Mode': 'Standard Class',
#  'State': 'Washington',
#  'Sub-Category': 'Paper',
#  '_id': ObjectId('67adea81fe577b36e55685f7')}
# {'Category': 'Furniture',
#  'City': 'Seattle',
#  'Country': 'United States',
#  'Customer ID': 'KC-16675',
#  'Customer Name': 'Kimberly Carter',
#  'Discount': 0.2,
#  'Order Date': '11-03-2017',
#  'Order ID': 'CA-2017-142636',
#  'Postal Code': 98105,
#  'Product ID': 'FUR-CH-10001891',
#  'Product Name': 'Global Deluxe Office Fabric Chairs',
#  'Profit': 26.8744,
#  'Quantity': 4,
#  'Region': 'West',
#  'Row ID': 416,
#  'Sales': 307.136,
#  'Segment': 'Corporate',
#  'Ship Date': '11-07-2017',
#  'Ship Mode': 'Standard Class',
#  'State': 'Washington',
#  'Sub-Category': 'Chairs',
#  '_id': ObjectId('67adea81fe577b36e55685f8')}
# {'Category': 'Office Supplies',
#  'City': 'Huntington Beach',
#  'Country': 'United States',
#  'Customer ID': 'CJ-12010',
#  'Customer Name': 'Caroline Jumper',
#  'Discount': 0.0,
#  'Order Date': '6/24/2017',
#  'Order ID': 'CA-2017-122105',
#  'Postal Code': 92646,
#  'Product ID': 'OFF-AR-10004344',
#  'Product Name': 'Bulldog Vacuum Base Pencil Sharpener',
#  'Profit': 25.8984,
#  'Quantity': 8,
#  'Region': 'West',
#  'Row ID': 417,
#  'Sales': 95.92,
#  'Segment': 'Consumer',
#  'Ship Date': '6/28/2017',
#  'Ship Mode': 'Standard Class',
#  'State': 'California',
#  'Sub-Category': 'Art',
#  '_id': ObjectId('67adea81fe577b36e55685f9')}
# {'Category': 'Furniture',
#  'City': 'Los Angeles',
#  'Country': 'United States',
#  'Customer ID': 'PB-19150',
#  'Customer Name': 'Philip Brown',
#  'Discount': 0.2,
#  'Order Date': '4/14/2016',
#  'Order ID': 'CA-2016-148796',
#  'Postal Code': 90004,
#  'Product ID': 'FUR-CH-10004886',
#  'Product Name': 'Bevis Steel Folding Chairs',
#  'Profit': 38.38,
#  'Quantity': 5,
#  'Region': 'West',
#  'Row ID': 418,
#  'Sales': 383.8,
#  'Segment': 'Consumer',
#  'Ship Date': '4/18/2016',
#  'Ship Mode': 'Standard Class',
#  'State': 'California',
#  'Sub-Category': 'Chairs',
#  '_id': ObjectId('67adea81fe577b36e55685fa')}
# {'Category': 'Technology',
#  'City': 'Louisville',
#  'Country': 'United States',
#  'Customer ID': 'JE-15745',
#  'Customer Name': 'Joel Eaton',
#  'Discount': 0.2,
#  'Order Date': '6/22/2014',
#  'Order ID': 'CA-2014-142048',
#  'Postal Code': 80027,
#  'Product ID': 'TEC-AC-10004114',
#  'Product Name': 'KeyTronic\xa06101 Series -\xa0Keyboard\xa0- Black',
#  'Profit': 56.5662,
#  'Quantity': 6,
#  'Region': 'West',
#  'Row ID': 422,
#  'Sales': 196.752,
#  'Segment': 'Consumer',
#  'Ship Date': '6/25/2014',
#  'Ship Mode': 'Premium Class',
#  'State': 'Colorado',
#  'Sub-Category': 'Accessories',
#  '_id': ObjectId('67adea81fe577b36e55685fe')}
# {'Category': 'Furniture',
#  'City': 'Concord',
#  'Country': 'United States',
#  'Customer ID': 'SC-20095',
#  'Customer Name': 'Sanjit Chand',
#  'Discount': 0.2,
#  'Order Date': '02-12-2014',
#  'Order ID': 'US-2014-110674',
#  'Postal Code': 94521,
#  'Product ID': 'FUR-CH-10000225',
#  'Product Name': 'Global Geo Office Task Chair, Gray',
#  'Profit': -24.294,
#  'Quantity': 2,
#  'Region': 'West',
#  'Row ID': 457,
#  'Sales': 129.568,
#  'Segment': 'Consumer',
#  'Ship Date': '2/18/2014',
#  'Ship Mode': 'Standard Class',
#  'State': 'California',
#  'Sub-Category': 'Chairs',
#  '_id': ObjectId('67adea81fe577b36e5568621')}
# {'Category': 'Office Supplies',
#  'City': 'Seattle',
#  'Country': 'United States',
#  'Customer ID': 'JH-15985',
#  'Customer Name': 'Joseph Holt',
#  'Discount': 0.0,
#  'Order Date': '12/15/2015',
#  'Order ID': 'CA-2015-109638',
#  'Postal Code': 98115,
#  'Product ID': 'OFF-AP-10002472',
#  'Product Name': '3M Office Air Cleaner',
#  'Profit': 36.372,
#  'Quantity': 4,
#  'Region': 'West',
#  'Row ID': 460,
#  'Sales': 103.92,
#  'Segment': 'Consumer',
#  'Ship Date': '12/22/2015',
#  'Ship Mode': 'Standard Class',
#  'State': 'Washington',
#  'Sub-Category': 'Appliances',
#  '_id': ObjectId('67adea81fe577b36e5568624')}
# {'Category': 'Technology',
#  'City': 'Seattle',
#  'Country': 'United States',
#  'Customer ID': 'JH-15985',
#  'Customer Name': 'Joseph Holt',
#  'Discount': 0.0,
#  'Order Date': '12/15/2015',
#  'Order ID': 'CA-2015-109638',
#  'Postal Code': 98115,
#  'Product ID': 'TEC-AC-10004571',
#  'Product Name': 'Logitech G700s Rechargeable Gaming Mouse',
#  'Profit': 377.9622,
#  'Quantity': 9,
#  'Region': 'West',
#  'Row ID': 461,
#  'Sales': 899.91,
#  'Segment': 'Consumer',
#  'Ship Date': '12/22/2015',
#  'Ship Mode': 'Standard Class',
#  'State': 'Washington',
#  'Sub-Category': 'Accessories',
#  '_id': ObjectId('67adea81fe577b36e5568625')}
# {'Category': 'Office Supplies',
#  'City': 'Seattle',
#  'Country': 'United States',
#  'Customer ID': 'JH-15985',
#  'Customer Name': 'Joseph Holt',
#  'Discount': 0.2,
#  'Order Date': '12/15/2015',
#  'Order ID': 'CA-2015-109638',
#  'Postal Code': 98115,
#  'Product ID': 'OFF-BI-10001098',
#  'Product Name': 'Acco D-Ring Binder w/DublLock',
#  'Profit': 18.6006,
#  'Quantity': 3,
#  'Region': 'West',
#  'Row ID': 462,
#  'Sales': 51.312,
#  'Segment': 'Consumer',
#  'Ship Date': '12/22/2015',
#  'Ship Mode': 'Standard Class',
#  'State': 'Washington',
#  'Sub-Category': 'Binders',
#  '_id': ObjectId('67adea81fe577b36e5568626')}
# {'Category': 'Furniture',
#  'City': 'Phoenix',
#  'Country': 'United States',
#  'Customer ID': 'TN-21040',
#  'Customer Name': 'Tanja Norvell',
#  'Discount': 0.5,
#  'Order Date': '4/22/2016',
#  'Order ID': 'CA-2016-109869',
#  'Postal Code': 85023,
#  'Product ID': 'FUR-TA-10001889',
#  'Product Name': 'Bush Advantage Collection Racetrack Conference Table',
#  'Profit': -814.4832,
#  'Quantity': 6,
#  'Region': 'West',
#  'Row ID': 464,
#  'Sales': 1272.63,
#  'Segment': 'Home Office',
#  'Ship Date': '4/29/2016',
# ...
#  '_id': ObjectId('67adea81fe577b36e556aacb')}
# {'Category': 'Furniture',
#  'City': 'Los Angeles',
#  'Country': 'United States',
#  'Customer ID': 'MH-17290',
#  'Customer Name': 'Marc Harrigan',
#  'Discount': 0.0,
#  'Order Date': '09-02-2017',
#  'Order ID': 'CA-2017-169327',
#  'Postal Code': 90008,
#  'Product ID': 'FUR-FU-10004188',
#  'Product Name': 'Luxo Professional Combination Clamp-On Lamps',
#  'Profit': 132.99,
#  'Quantity': 5,
#  'Region': 'West',
#  'Row ID': 9848,
#  'Sales': 511.5,
#  'Segment': 'Home Office',
#  'Ship Date': '09-04-2017',
#  'Ship Mode': 'Second Class',
#  'State': 'California',
#  'Sub-Category': 'Furnishings',
#  '_id': ObjectId('67adea81fe577b36e556aad0')}
# {'Category': 'Office Supplies',
#  'City': 'Los Angeles',
#  'Country': 'United States',
#  'Customer ID': 'MH-17290',
#  'Customer Name': 'Marc Harrigan',
#  'Discount': 0.2,
#  'Order Date': '09-02-2017',
#  'Order ID': 'CA-2017-169327',
#  'Postal Code': 90008,
#  'Product ID': 'OFF-BI-10004330',
#  'Product Name': 'GBC Velobind Prepunched Cover Sets, Regency Series',
#  'Profit': 46.225,
#  'Quantity': 5,
#  'Region': 'West',
#  'Row ID': 9849,
#  'Sales': 147.92,
#  'Segment': 'Home Office',
#  'Ship Date': '09-04-2017',
#  'Ship Mode': 'Second Class',
#  'State': 'California',
#  'Sub-Category': 'Binders',
#  '_id': ObjectId('67adea81fe577b36e556aad1')}
# {'Category': 'Furniture',
#  'City': 'San Francisco',
#  'Country': 'United States',
#  'Customer ID': 'GA-14515',
#  'Customer Name': 'George Ashbrook',
#  'Discount': 0.0,
#  'Order Date': '6/19/2017',
#  'Order ID': 'CA-2017-138870',
#  'Postal Code': 94109,
#  'Product ID': 'FUR-FU-10002396',
#  'Product Name': 'DAX Copper Panel Document Frame, 5 x 7 Size',
#  'Profit': 21.1344,
#  'Quantity': 4,
#  'Region': 'West',
#  'Row ID': 9855,
#  'Sales': 50.32,
#  'Segment': 'Consumer',
#  'Ship Date': '6/23/2017',
#  'Ship Mode': 'Standard Class',
#  'State': 'California',
#  'Sub-Category': 'Furnishings',
#  '_id': ObjectId('67adea81fe577b36e556aad7')}
# {'Category': 'Furniture',
#  'City': 'Seattle',
#  'Country': 'United States',
#  'Customer ID': 'EB-13840',
#  'Customer Name': 'Ellis Ballard',
#  'Discount': 0.0,
#  'Order Date': '3/26/2015',
#  'Order ID': 'CA-2015-164301',
#  'Postal Code': 98103,
#  'Product ID': 'FUR-TA-10001889',
#  'Product Name': 'Bush Advantage Collection Racetrack Conference Table',
#  'Profit': 610.8624,
#  'Quantity': 8,
#  'Region': 'West',
#  'Row ID': 9858,
#  'Sales': 3393.68,
#  'Segment': 'Corporate',
#  'Ship Date': '3/30/2015',
#  'Ship Mode': 'Standard Class',
#  'State': 'Washington',
#  'Sub-Category': 'Tables',
#  '_id': ObjectId('67adea81fe577b36e556aada')}
# {'Category': 'Technology',
#  'City': 'Los Angeles',
#  'Country': 'United States',
#  'Customer ID': 'KE-16420',
#  'Customer Name': 'Katrina Edelman',
#  'Discount': 0.0,
#  'Order Date': '04-03-2014',
#  'Order ID': 'CA-2014-112291',
#  'Postal Code': 90008,
#  'Product ID': 'TEC-AC-10001284',
#  'Product Name': 'Enermax Briskie RF Wireless Keyboard and Mouse Combo',
#  'Profit': 22.4316,
#  'Quantity': 3,
#  'Region': 'West',
#  'Row ID': 9885,
#  'Sales': 62.31,
#  'Segment': 'Corporate',
#  'Ship Date': '04-08-2014',
#  'Ship Mode': 'Standard Class',
#  'State': 'California',
#  'Sub-Category': 'Accessories',
#  '_id': ObjectId('67adea81fe577b36e556aaf5')}
# {'Category': 'Technology',
#  'City': 'Los Angeles',
#  'Country': 'United States',
#  'Customer ID': 'KE-16420',
#  'Customer Name': 'Katrina Edelman',
#  'Discount': 0.0,
#  'Order Date': '04-03-2014',
#  'Order ID': 'CA-2014-112291',
#  'Postal Code': 90008,
#  'Product ID': 'TEC-AC-10000736',
#  'Product Name': 'Logitech G600 MMO Gaming Mouse',
#  'Profit': 57.5928,
#  'Quantity': 2,
#  'Region': 'West',
#  'Row ID': 9886,
#  'Sales': 159.98,
#  'Segment': 'Corporate',
#  'Ship Date': '04-08-2014',
#  'Ship Mode': 'Standard Class',
#  'State': 'California',
#  'Sub-Category': 'Accessories',
#  '_id': ObjectId('67adea81fe577b36e556aaf6')}
# {'Category': 'Office Supplies',
#  'City': 'Louisville',
#  'Country': 'United States',
#  'Customer ID': 'SC-20845',
#  'Customer Name': 'Sung Chung',
#  'Discount': 0.2,
#  'Order Date': '8/21/2017',
#  'Order ID': 'CA-2017-117646',
#  'Postal Code': 80027,
#  'Product ID': 'OFF-ST-10000036',
#  'Product Name': 'Recycled Data-Pak for Archival Bound Computer Printouts, '
#                  '12-1/2 x 12-1/2 x 16',
#  'Profit': 20.7459,
#  'Quantity': 3,
#  'Region': 'West',
#  'Row ID': 9901,
#  'Sales': 237.096,
#  'Segment': 'Consumer',
#  'Ship Date': '8/25/2017',
#  'Ship Mode': 'Standard Class',
#  'State': 'Colorado',
#  'Sub-Category': 'Storage',
#  '_id': ObjectId('67adea81fe577b36e556ab05')}
# {'Category': 'Furniture',
#  'City': 'Anaheim',
#  'Country': 'United States',
#  'Customer ID': 'KD-16615',
#  'Customer Name': 'Ken Dana',
#  'Discount': 0.0,
#  'Order Date': '9/13/2015',
#  'Order ID': 'US-2015-129007',
#  'Postal Code': 92804,
#  'Product ID': 'FUR-FU-10004973',
#  'Product Name': 'Flat Face Poster Frame',
#  'Profit': 55.3896,
#  'Quantity': 7,
#  'Region': 'West',
#  'Row ID': 9906,
#  'Sales': 131.88,
#  'Segment': 'Corporate',
#  'Ship Date': '9/15/2015',
#  'Ship Mode': 'Premium Class',
#  'State': 'California',
#  'Sub-Category': 'Furnishings',
#  '_id': ObjectId('67adea81fe577b36e556ab0a')}
# {'Category': 'Furniture',
#  'City': 'Anaheim',
#  'Country': 'United States',
#  'Customer ID': 'KD-16615',
#  'Customer Name': 'Ken Dana',
#  'Discount': 0.2,
#  'Order Date': '9/13/2015',
#  'Order ID': 'US-2015-129007',
#  'Postal Code': 92804,
#  'Product ID': 'FUR-CH-10000155',
#  'Product Name': 'Global Comet Stacking Armless Chair',
#  'Profit': 71.772,
#  'Quantity': 3,
#  'Region': 'West',
#  'Row ID': 9908,
#  'Sales': 717.72,
#  'Segment': 'Corporate',
#  'Ship Date': '9/15/2015',
#  'Ship Mode': 'Premium Class',
#  'State': 'California',
#  'Sub-Category': 'Chairs',
#  '_id': ObjectId('67adea81fe577b36e556ab0c')}
# {'Category': 'Furniture',
#  'City': 'Anaheim',
#  'Country': 'United States',
#  'Customer ID': 'KD-16615',
#  'Customer Name': 'Ken Dana',
#  'Discount': 0.0,
#  'Order Date': '9/13/2015',
#  'Order ID': 'US-2015-129007',
#  'Postal Code': 92804,
#  'Product ID': 'FUR-FU-10002379',
#  'Product Name': 'Eldon Econocleat Chair Mats for Low Pile Carpets',
#  'Profit': 24.882,
#  'Quantity': 5,
#  'Region': 'West',
#  'Row ID': 9909,
#  'Sales': 207.35,
#  'Segment': 'Corporate',
#  'Ship Date': '9/15/2015',
#  'Ship Mode': 'Premium Class',
#  'State': 'California',
#  'Sub-Category': 'Furnishings',
#  '_id': ObjectId('67adea81fe577b36e556ab0d')}
# {'Category': 'Office Supplies',
#  'City': 'Anaheim',
#  'Country': 'United States',
#  'Customer ID': 'KD-16615',
#  'Customer Name': 'Ken Dana',
#  'Discount': 0.0,
#  'Order Date': '9/13/2015',
#  'Order ID': 'US-2015-129007',
#  'Postal Code': 92804,
#  'Product ID': 'OFF-PA-10000994',
#  'Product Name': 'Xerox 1915',
#  'Profit': 100.656,
#  'Quantity': 2,
#  'Region': 'West',
#  'Row ID': 9911,
#  'Sales': 209.7,
#  'Segment': 'Corporate',
#  'Ship Date': '9/15/2015',
#  'Ship Mode': 'Premium Class',
#  'State': 'California',
#  'Sub-Category': 'Paper',
#  '_id': ObjectId('67adea81fe577b36e556ab0f')}
# {'Category': 'Furniture',
#  'City': 'Santa Barbara',
#  'Country': 'United States',
#  'Customer ID': 'KN-16390',
#  'Customer Name': 'Katherine Nockton',
#  'Discount': 0.2,
#  'Order Date': '10-10-2015',
#  'Order ID': 'CA-2015-132388',
#  'Postal Code': 93101,
#  'Product ID': 'FUR-CH-10001714',
#  'Product Name': 'Global Leather & Oak Executive Chair, Burgundy',
#  'Profit': -54.3204,
#  'Quantity': 3,
#  'Region': 'West',
#  'Row ID': 9913,
#  'Sales': 362.136,
#  'Segment': 'Corporate',
#  'Ship Date': '10-12-2015',
#  'Ship Mode': 'Premium Class',
#  'State': 'California',
#  'Sub-Category': 'Chairs',
#  '_id': ObjectId('67adea81fe577b36e556ab11')}
# {'Category': 'Technology',
#  'City': 'San Francisco',
#  'Country': 'United States',
#  'Customer ID': 'IM-15055',
#  'Customer Name': 'Ionia McGrath',
#  'Discount': 0.2,
#  'Order Date': '09-04-2016',
#  'Order ID': 'CA-2016-129630',
#  'Postal Code': 94122,
#  'Product ID': 'TEC-CO-10003763',
#  'Product Name': 'Canon PC1060 Personal Laser Copier',
#  'Profit': 944.9865,
#  'Quantity': 5,
#  'Region': 'West',
#  'Row ID': 9930,
#  'Sales': 2799.96,
#  'Segment': 'Consumer',
#  'Ship Date': '09-04-2016',
#  'Ship Mode': 'Same Day',
#  'State': 'California',
#  'Sub-Category': 'Copiers',
#  '_id': ObjectId('67adea81fe577b36e556ab22')}
# {'Category': 'Furniture',
#  'City': 'San Bernardino',
#  'Country': 'United States',
#  'Customer ID': 'KH-16510',
#  'Customer Name': 'Keith Herrera',
#  'Discount': 0.15,
#  'Order Date': '11/13/2015',
#  'Order ID': 'CA-2015-104948',
#  'Postal Code': 92404,
#  'Product ID': 'FUR-BO-10004357',
#  'Product Name': "O'Sullivan Living Dimensions 3-Shelf Bookcases",
#  'Profit': -40.196,
#  'Quantity': 4,
#  'Region': 'West',
#  'Row ID': 9932,
#  'Sales': 683.332,
#  'Segment': 'Consumer',
#  'Ship Date': '11/17/2015',
#  'Ship Mode': 'Standard Class',
#  'State': 'California',
#  'Sub-Category': 'Bookcases',
#  '_id': ObjectId('67adea81fe577b36e556ab24')}
# {'Category': 'Furniture',
#  'City': 'Los Angeles',
#  'Country': 'United States',
#  'Customer ID': 'CP-12340',
#  'Customer Name': 'Christine Phan',
#  'Discount': 0.2,
#  'Order Date': '06-03-2016',
#  'Order ID': 'CA-2016-164889',
#  'Postal Code': 90049,
#  'Product ID': 'FUR-TA-10001676',
#  'Product Name': 'Hon 61000 Series Interactive Training Tables',
#  'Profit': -1.7772,
#  'Quantity': 2,
#  'Region': 'West',
#  'Row ID': 9938,
#  'Sales': 71.088,
#  'Segment': 'Corporate',
#  'Ship Date': '06-06-2016',
#  'Ship Mode': 'Second Class',
#  'State': 'California',
#  'Sub-Category': 'Tables',
#  '_id': ObjectId('67adea81fe577b36e556ab2a')}
# {'Category': 'Technology',
#  'City': 'San Francisco',
#  'Country': 'United States',
#  'Customer ID': 'JL-15835',
#  'Customer Name': 'John Lee',
#  'Discount': 0.0,
#  'Order Date': '11/24/2017',
#  'Order ID': 'CA-2017-164028',
#  'Postal Code': 94122,
#  'Product ID': 'TEC-AC-10001772',
#  'Product Name': 'Memorex Mini Travel Drive 16 GB USB 2.0 Flash Drive',
#  'Profit': 87.1962,
#  'Quantity': 14,
#  'Region': 'West',
#  'Row ID': 9942,
#  'Sales': 223.58,
#  'Segment': 'Consumer',
#  'Ship Date': '11/30/2017',
#  'Ship Mode': 'Standard Class',
#  'State': 'California',
#  'Sub-Category': 'Accessories',
#  '_id': ObjectId('67adea81fe577b36e556ab2e')}
# {'Category': 'Office Supplies',
#  'City': 'Anaheim',
#  'Country': 'United States',
#  'Customer ID': 'MD-17350',
#  'Customer Name': 'Maribeth Dona',
#  'Discount': 0.0,
#  'Order Date': '12/28/2014',
#  'Order ID': 'CA-2014-143371',
#  'Postal Code': 92804,
#  'Product ID': 'OFF-ST-10001128',
#  'Product Name': 'Carina Mini System Audio Rack, Model AR050B',
#  'Profit': 29.9646,
#  'Quantity': 9,
#  'Region': 'West',
#  'Row ID': 9943,
#  'Sales': 998.82,
#  'Segment': 'Consumer',
#  'Ship Date': '01-03-2015',
#  'Ship Mode': 'Standard Class',
#  'State': 'California',
#  'Sub-Category': 'Storage',
#  '_id': ObjectId('67adea81fe577b36e556ab2f')}
# {'Category': 'Office Supplies',
#  'City': 'Anaheim',
#  'Country': 'United States',
#  'Customer ID': 'MD-17350',
#  'Customer Name': 'Maribeth Dona',
#  'Discount': 0.0,
#  'Order Date': '12/28/2014',
#  'Order ID': 'CA-2014-143371',
#  'Postal Code': 92804,
#  'Product ID': 'OFF-SU-10002537',
#  'Product Name': 'Acme Box Cutter Scissors',
#  'Profit': 13.299,
#  'Quantity': 5,
#  'Region': 'West',
#  'Row ID': 9944,
#  'Sales': 51.15,
#  'Segment': 'Consumer',
#  'Ship Date': '01-03-2015',
#  'Ship Mode': 'Standard Class',
#  'State': 'California',
#  'Sub-Category': 'Supplies',
#  '_id': ObjectId('67adea81fe577b36e556ab30')}
# {'Category': 'Office Supplies',
#  'City': 'Los Angeles',
#  'Country': 'United States',
#  'Customer ID': 'DB-12970',
#  'Customer Name': 'Darren Budd',
#  'Discount': 0.2,
#  'Order Date': '12/14/2015',
#  'Order ID': 'CA-2015-141593',
#  'Postal Code': 90045,
#  'Product ID': 'OFF-BI-10001153',
#  'Product Name': 'Ibico Recycled Grain-Textured Covers',
#  'Profit': 20.724,
#  'Quantity': 2,
#  'Region': 'West',
#  'Row ID': 9953,
#  'Sales': 55.264,
#  'Segment': 'Corporate',
#  'Ship Date': '12/16/2015',
#  'Ship Mode': 'Second Class',
#  'State': 'California',
#  'Sub-Category': 'Binders',
#  '_id': ObjectId('67adea81fe577b36e556ab39')}
# {'Category': 'Furniture',
#  'City': 'Los Angeles',
#  'Country': 'United States',
#  'Customer ID': 'DB-12970',
#  'Customer Name': 'Darren Budd',
#  'Discount': 0.2,
#  'Order Date': '12/14/2015',
#  'Order ID': 'CA-2015-141593',
#  'Postal Code': 90045,
#  'Product ID': 'FUR-TA-10002622',
#  'Product Name': 'Bush Andora Conference Table, Maple/Graphite Gray Finish',
#  'Profit': 10.2588,
#  'Quantity': 2,
#  'Region': 'West',
#  'Row ID': 9956,
#  'Sales': 273.568,
#  'Segment': 'Corporate',
#  'Ship Date': '12/16/2015',
#  'Ship Mode': 'Second Class',
#  'State': 'California',
#  'Sub-Category': 'Tables',
#  '_id': ObjectId('67adea81fe577b36e556ab3c')}
# {'Category': 'Technology',
#  'City': 'Los Angeles',
#  'Country': 'United States',
#  'Customer ID': 'AP-10720',
#  'Customer Name': 'Anne Pryor',
#  'Discount': 0.2,
#  'Order Date': '12-06-2016',
#  'Order ID': 'US-2016-103674',
#  'Postal Code': 90032,
#  'Product ID': 'TEC-PH-10004080',
#  'Product Name': 'Avaya 5410 Digital phone',
#  'Profit': 27.196,
#  'Quantity': 5,
#  'Region': 'West',
#  'Row ID': 9974,
#  'Sales': 271.96,
#  'Segment': 'Home Office',
#  'Ship Date': '12-10-2016',
#  'Ship Mode': 'Standard Class',
#  'State': 'California',
#  'Sub-Category': 'Phones',
#  '_id': ObjectId('67adea81fe577b36e556ab4e')}
# {'Category': 'Technology',
#  'City': 'Los Angeles',
#  'Country': 'United States',
#  'Customer ID': 'AP-10720',
#  'Customer Name': 'Anne Pryor',
#  'Discount': 0.2,
#  'Order Date': '12-06-2016',
#  'Order ID': 'US-2016-103674',
#  'Postal Code': 90032,
#  'Product ID': 'TEC-PH-10002496',
#  'Product Name': 'Cisco SPA301',
#  'Profit': 31.198,
#  'Quantity': 2,
#  'Region': 'West',
#  'Row ID': 9977,
#  'Sales': 249.584,
#  'Segment': 'Home Office',
#  'Ship Date': '12-10-2016',
#  'Ship Mode': 'Standard Class',
#  'State': 'California',
#  'Sub-Category': 'Phones',
#  '_id': ObjectId('67adea81fe577b36e556ab51')}
# {'Category': 'Office Supplies',
#  'City': 'Los Angeles',
#  'Country': 'United States',
#  'Customer ID': 'AP-10720',
#  'Customer Name': 'Anne Pryor',
#  'Discount': 0.2,
#  'Order Date': '12-06-2016',
#  'Order ID': 'US-2016-103674',
#  'Postal Code': 90032,
#  'Product ID': 'OFF-BI-10002026',
#  'Product Name': 'Ibico Recycled Linen-Style Covers',
#  'Profit': 153.1152,
#  'Quantity': 14,
#  'Region': 'West',
#  'Row ID': 9980,
#  'Sales': 437.472,
#  'Segment': 'Home Office',
#  'Ship Date': '12-10-2016',
#  'Ship Mode': 'Standard Class',
#  'State': 'California',
#  'Sub-Category': 'Binders',
#  '_id': ObjectId('67adea81fe577b36e556ab54')}
# {'Category': 'Furniture',
#  'City': 'Costa Mesa',
#  'Country': 'United States',
#  'Customer ID': 'DB-13060',
#  'Customer Name': 'Dave Brooks',
#  'Discount': 0.0,
#  'Order Date': '2/26/2017',
#  'Order ID': 'CA-2017-121258',
#  'Postal Code': 92627,
#  'Product ID': 'FUR-FU-10000747',
#  'Product Name': 'Tenex B1-RE Series Chair Mats for Low Pile Carpets',
#  'Profit': 15.6332,
#  'Quantity': 2,
#  'Region': 'West',
#  'Row ID': 9991,
#  'Sales': 91.96,
#  'Segment': 'Consumer',
#  'Ship Date': '03-03-2017',
#  'Ship Mode': 'Standard Class',
#  'State': 'California',
#  'Sub-Category': 'Furnishings',
#  '_id': ObjectId('67adea81fe577b36e556ab5f')}
# {'Category': 'Technology',
#  'City': 'Costa Mesa',
#  'Country': 'United States',
#  'Customer ID': 'DB-13060',
#  'Customer Name': 'Dave Brooks',
#  'Discount': 0.2,
#  'Order Date': '2/26/2017',
#  'Order ID': 'CA-2017-121258',
#  'Postal Code': 92627,
#  'Product ID': 'TEC-PH-10003645',
#  'Product Name': 'Aastra 57i VoIP phone',
#  'Profit': 19.3932,
#  'Quantity': 2,
#  'Region': 'West',
#  'Row ID': 9992,
#  'Sales': 258.576,
#  'Segment': 'Consumer',
#  'Ship Date': '03-03-2017',
#  'Ship Mode': 'Standard Class',
#  'State': 'California',
#  'Sub-Category': 'Phones',
#  '_id': ObjectId('67adea81fe577b36e556ab60')}
# {'Category': 'Office Supplies',
#  'City': 'Westminster',
#  'Country': 'United States',
#  'Customer ID': 'CC-12220',
#  'Customer Name': 'Chris Cortes',
#  'Discount': 0.0,
#  'Order Date': '05-04-2017',
#  'Order ID': 'CA-2017-119914',
#  'Postal Code': 92683,
#  'Product ID': 'OFF-AP-10002684',
#  'Product Name': 'Acco 7-Outlet Masterpiece Power Center, Wihtout Fax/Phone '
#                  'Line Protection',
#  'Profit': 72.948,
#  'Quantity': 2,
#  'Region': 'West',
#  'Row ID': 9994,
#  'Sales': 243.16,
#  'Segment': 'Consumer',
#  'Ship Date': '05-09-2017',
#  'Ship Mode': 'Second Class',
#  'State': 'California',
#  'Sub-Category': 'Appliances',
#  '_id': ObjectId('67adea81fe577b36e556ab62')}

# %%
#5.Write a query to find orders where Sales is greater than 500
sales_gt_500 = collection.find({"Sales": {"$gt": 500}}).limit(2)

# Print the orders
for order in sales_gt_500:
    pprint.pprint(order)
# Out:
# {'Category': 'Furniture',
#  'City': 'Henderson',
#  'Country': 'United States',
#  'Customer ID': 'CG-12520',
#  'Customer Name': 'Claire Gute',
#  'Discount': 0.0,
#  'Order Date': '11-08-2016',
#  'Order ID': 'CA-2016-152156',
#  'Postal Code': 42420,
#  'Product ID': 'FUR-CH-10000454',
#  'Product Name': 'Hon Deluxe Fabric Upholstered Stacking Chairs, Rounded Back',
#  'Profit': 219.582,
#  'Quantity': 3,
#  'Region': 'South',
#  'Row ID': 2,
#  'Sales': 731.94,
#  'Segment': 'Consumer',
#  'Ship Date': '11-11-2016',
#  'Ship Mode': 'Second Class',
#  'State': 'Kentucky',
#  'Sub-Category': 'Chairs',
#  '_id': ObjectId('67adea81fe577b36e556845a')}
# {'Category': 'Furniture',
#  'City': 'Fort Lauderdale',
#  'Country': 'United States',
#  'Customer ID': 'SO-20335',
#  'Customer Name': "Sean O'Donnell",
#  'Discount': 0.45,
#  'Order Date': '10-11-2015',
#  'Order ID': 'US-2015-108966',
#  'Postal Code': 33311,
#  'Product ID': 'FUR-TA-10000577',
#  'Product Name': 'Bretford CR4500 Series Slim Rectangular Table',
#  'Profit': -383.031,
#  'Quantity': 5,
#  'Region': 'South',
#  'Row ID': 4,
#  'Sales': 957.5775,
#  'Segment': 'Consumer',
#  'Ship Date': '10/18/2015',
#  'Ship Mode': 'Standard Class',
#  'State': 'Florida',
#  'Sub-Category': 'Tables',
#  '_id': ObjectId('67adea81fe577b36e556845c')}

# %%
#6. Fetch the top 3 orders with the highest Profit
top_profit_orders = collection.find().sort("Profit", -1).limit(3)

# Print the top 3 profitable orders
for order in top_profit_orders:
    print(order)
# Out:
# {'_id': ObjectId('67adea81fe577b36e5569f03'), 'Row ID': 6827, 'Order ID': 'CA-2016-118689', 'Order Date': '10-02-2016', 'Ship Date': '10-09-2016', 'Ship Mode': 'Standard Class', 'Customer ID': 'TC-20980', 'Customer Name': 'Tamara Chand', 'Segment': 'Corporate', 'Country': 'United States', 'City': 'Lafayette', 'State': 'Indiana', 'Postal Code': 47905, 'Region': 'Central', 'Product ID': 'TEC-CO-10004722', 'Category': 'Technology', 'Sub-Category': 'Copiers', 'Product Name': 'Canon imageCLASS 2200 Advanced Copier', 'Sales': 17499.95, 'Quantity': 5, 'Discount': 0.0, 'Profit': 8399.976}
# {'_id': ObjectId('67adea81fe577b36e556a432'), 'Row ID': 8154, 'Order ID': 'CA-2017-140151', 'Order Date': '3/23/2017', 'Ship Date': '3/25/2017', 'Ship Mode': 'First Class', 'Customer ID': 'RB-19360', 'Customer Name': 'Raymond Buch', 'Segment': 'Consumer', 'Country': 'United States', 'City': 'Seattle', 'State': 'Washington', 'Postal Code': 98115, 'Region': 'West', 'Product ID': 'TEC-CO-10004722', 'Category': 'Technology', 'Sub-Category': 'Copiers', 'Product Name': 'Canon imageCLASS 2200 Advanced Copier', 'Sales': 13999.96, 'Quantity': 4, 'Discount': 0.0, 'Profit': 6719.9808}
# {'_id': ObjectId('67adea81fe577b36e55694b7'), 'Row ID': 4191, 'Order ID': 'CA-2017-166709', 'Order Date': '11/17/2017', 'Ship Date': '11/22/2017', 'Ship Mode': 'Standard Class', 'Customer ID': 'HL-15040', 'Customer Name': 'Hunter Lopez', 'Segment': 'Consumer', 'Country': 'United States', 'City': 'Newark', 'State': 'Delaware', 'Postal Code': 19711, 'Region': 'East', 'Product ID': 'TEC-CO-10004722', 'Category': 'Technology', 'Sub-Category': 'Copiers', 'Product Name': 'Canon imageCLASS 2200 Advanced Copier', 'Sales': 10499.97, 'Quantity': 3, 'Discount': 0.0, 'Profit': 5039.9856}

# %%
#7. Update all orders with Ship Mode as "First Class" to "Premium Class.

update_result = collection.update_many(
    {"Ship Mode": "First Class"},  # Filter condition
    {"$set": {"Ship Mode": "Premium Class"}}  # Update operation
)

# Print the number of documents updated
print("Total documents updated:", update_result.modified_count)
# Out:
# Total documents updated: 1538

# %%
#8. Delete all orders where Sales is less than 50
# Delete all orders where Sales is less than 50
delete_result = collection.delete_many({"Sales": {"$lt": 50}})

# Print the number of documents deleted
print("Total documents deleted:", delete_result.deleted_count)
# Out:
# Total documents deleted: 4849

# %%
#9.Use aggregation to group orders by Region and calculate total sales per region
# Aggregation pipeline to group by Region and calculate total Sales
pipeline = [
    {"$group": {
        "_id": "$Region",   # Group by Region
        "Total Sales": {"$sum": "$Sales"}  # Sum of Sales per region
    }}
]

# Execute the aggregation query
results = collection.aggregate(pipeline)

# Print the results
for result in results:
    print(result)
# Out:
# {'_id': 'West', 'Total Sales': 694686.6195}
# {'_id': 'Central', 'Total Sales': 479611.8458}
# {'_id': 'South', 'Total Sales': 376023.312}
# {'_id': 'East', 'Total Sales': 651137.705}

# %%
#10. Fetch all distinct values for Ship Mode from the collection
# Fetch all distinct values for Ship Mode
distinct_ship_modes = collection.distinct("Ship Mode")

# Print the distinct ship modes
print("Distinct Ship Modes:", distinct_ship_modes)
# Out:
# Distinct Ship Modes: ['Premium Class', 'Same Day', 'Second Class', 'Standard Class']

# %%
#11.Count the number of orders for each category.
# Aggregation pipeline to count orders per category
pipeline = [
    {"$group": {
        "_id": "$Category",  # Group by Category
        "Order Count": {"$sum": 1}  # Count number of documents (orders)
    }}
]

# Execute the aggregation query
results = collection.aggregate(pipeline)

# Print the results
for result in results:
    print(result)
# Out:
# {'_id': 'Furniture', 'Order Count': 1573}
# {'_id': 'Technology', 'Order Count': 1496}
# {'_id': 'Office Supplies', 'Order Count': 2076}
